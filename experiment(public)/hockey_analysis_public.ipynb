# %%
import sqlite3

import mysql.connector
from mysql.connector import Error
from itertools import combinations
import time
from collections import Counter
from prettytable import PrettyTable
import json, os, getpass, pathlib

# %% [markdown]
# # --- Config loader for MySQL connection (portable & secure) ---

# %%
def load_mysql_config():
    """
    Load MySQL config with the following precedence:
    1) Environment variables: MYSQL_HOST / MYSQL_PORT / MYSQL_USER / MYSQL_PASSWORD / MYSQL_DATABASE
    2) config/config.json (user-specific, not committed)
    3) Interactive prompt (safe password input)
    """
    # 1) Try environment variables first
    env = {
        "host": os.getenv("MYSQL_HOST"),
        "port": os.getenv("MYSQL_PORT"),
        "user": os.getenv("MYSQL_USER"),
        "password": os.getenv("MYSQL_PASSWORD"),
        "database": os.getenv("MYSQL_DATABASE"),
    }
    if all(env.values()):
        try:
            env["port"] = int(env["port"])
        except ValueError:
            raise ValueError("MYSQL_PORT must be an integer.")
        return env

    # 2) Try config/config.json
    cfg_path = pathlib.Path("config/config.json")
    if cfg_path.exists():
        with open(cfg_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        mysql = data.get("mysql", {})
        if {"host","port","user","password","database"} <= set(mysql.keys()):
            return {
                "host": mysql["host"],
                "port": int(mysql["port"]),
                "user": mysql["user"],
                "password": mysql["password"],
                "database": mysql["database"],
            }

    # 3) Fallback: prompt the user (no echo for password)
    print("No environment variables or config/config.json found.")
    host = input("MySQL host [localhost]: ") or "localhost"
    port_str = input("MySQL port [3306]: ") or "3306"
    user = input("MySQL user [root]: ") or "root"
    database = input("MySQL database [Hockey]: ") or "Hockey"
    password = getpass.getpass("MySQL password (input hidden): ")

    try:
        port = int(port_str)
    except ValueError:
        raise ValueError("Port must be an integer.")

    return {"host": host, "port": port, "user": user, "password": password, "database": database}

mysql_cfg = load_mysql_config()
print(f"✔ Using MySQL @ {mysql_cfg['user']}@{mysql_cfg['host']}:{mysql_cfg['port']} / DB={mysql_cfg['database']}")
# Out:
# No environment variables or config/config.json found.
# ✔ Using MySQL @ root@localhost:3306 / DB=Hockey

# %% [markdown]
# # 10 tables

# %%
l1 = {
    'abbrev': ['Type', 'Code', 'Fullname'],
    'awardscoaches': ['coachID', 'award', 'year', 'lgID'],
    'awardsmisc': ['name', 'ID', 'award', 'year', 'lgID'],
    'awardsplayers': ['playerID', 'award', 'year', 'lgID', 'pos'],
    'coaches': ['coachID', 'year', 'tmID', 'lgID', 'stint'],
    'combinedshutouts': ['year', 'month', 'date', 'tmID', 'oppID', 'R/P', 'IDgoalie1', 'IDgoalie2'],
    'goalies': ['playerID', 'year', 'stint', 'tmID', 'lgID', 'GP'],
    'goaliessc': ['playerID', 'year', 'tmID', 'lgID', 'GP'],
    'goaliesshootout': ['playerID', 'year', 'stint', 'tmID'],
    'hof': ['year', 'hofID', 'name', 'category'],
    'master': ['playerID', 'coachID', 'hofID', 'legendsID', 'ihdbID', 'hrefID', 'lastName', 'nameGiven', 'birthYear', 'pos'],
    'scoring': ['playerID', 'year', 'stint', 'tmID', 'lgID', 'pos'],
    'scoringsc': ['playerID', 'year', 'tmID', 'lgID', 'pos'],
    'scoringshootout': ['playerID', 'year', 'stint', 'tmID'],
    'scoringsup': ['playerID', 'year'],
    'seriespost': ['year', 'round', 'series', 'tmIDWinner', 'lgIDWinner', 'tmIDLoser', 'lgIDLoser'],
    'teams': ['year', 'lgID', 'tmID', 'franchID', 'confID', 'divID', 'rank', 'name'],
    'teamshalf': ['year', 'lgID', 'tmID', 'half', 'rank'],
    'teamsplits': ['year', 'lgID', 'tmID'],
    'teamspost': ['year', 'lgID', 'tmID'],
    'teamssc': ['year', 'lgID', 'tmID'],
    'teamvsteam': ['year', 'lgID', 'tmID', 'oppID']
}

total_table = PrettyTable()
total_table.field_names = ['Table Name', 'Columns']


for key, values in l1.items():
    col = ', '.join(v for v in values)
    total_table.add_row([key, col])
    
print(total_table)
# Out:
# +------------------+------------------------------------------------------------------------------------------+
# |    Table Name    |                                         Columns                                          |
# +------------------+------------------------------------------------------------------------------------------+
# |      abbrev      |                                   Type, Code, Fullname                                   |
# |  awardscoaches   |                                coachID, award, year, lgID                                |
# |    awardsmisc    |                               name, ID, award, year, lgID                                |
# |  awardsplayers   |                             playerID, award, year, lgID, pos                             |
# |     coaches      |                             coachID, year, tmID, lgID, stint                             |
# | combinedshutouts |                year, month, date, tmID, oppID, R/P, IDgoalie1, IDgoalie2                 |
# |     goalies      |                          playerID, year, stint, tmID, lgID, GP                           |
# |    goaliessc     |                              playerID, year, tmID, lgID, GP                              |
# | goaliesshootout  |                               playerID, year, stint, tmID                                |
# |       hof        |                               year, hofID, name, category                                |
# |      master      | playerID, coachID, hofID, legendsID, ihdbID, hrefID, lastName, nameGiven, birthYear, pos |
# |     scoring      |                          playerID, year, stint, tmID, lgID, pos                          |
# |    scoringsc     |                             playerID, year, tmID, lgID, pos                              |
# | scoringshootout  |                               playerID, year, stint, tmID                                |
# |    scoringsup    |                                      playerID, year                                      |
# |    seriespost    |            year, round, series, tmIDWinner, lgIDWinner, tmIDLoser, lgIDLoser             |
# |      teams       |                  year, lgID, tmID, franchID, confID, divID, rank, name                   |
# |    teamshalf     |                               year, lgID, tmID, half, rank                               |
# |    teamsplits    |                                     year, lgID, tmID                                     |
# |    teamspost     |                                     year, lgID, tmID                                     |
# |     teamssc      |                                     year, lgID, tmID                                     |
# |    teamvsteam    |                                 year, lgID, tmID, oppID                                  |
# +------------------+------------------------------------------------------------------------------------------+

# %% [markdown]
# # Method
# ## Uniqueness Ratio
# ## Completeness Ratio

# %%
def get_column_names(cursor, table_name):
    """Get all column names of a database table"""
    cursor.execute(f"DESCRIBE `{table_name}`")
    return [column[0] for column in cursor.fetchall()]


# Uniqueness Ratio
def pmax_uniqueness_ratio_sql(cursor, table_name, columns):
    """Calculates the Uniqueness Ratio for a given column permutation"""
    if not columns:
        return 0, 0
    columns_list = ', '.join([f"`{col}`" for col in columns])
    query = f"""
        SELECT
            ((null_rows + unique_rows) / total_rows) AS uniqueness_ratio
        FROM (
            SELECT
                (SELECT COUNT(*) FROM {table_name} WHERE {' OR '.join([f"`{col}` IS NULL" for col in columns])}) AS null_rows,
                (
                    SELECT COUNT(*)
                    FROM (
                        SELECT {columns_list}
                        FROM `{table_name}`
                        WHERE {' AND '.join([f"`{col}` IS NOT NULL" for col in columns])}
                        GROUP BY {columns_list}
                        HAVING COUNT(*) = 1
                    ) AS unique_data
                ) AS unique_rows,
                (SELECT COUNT(*) FROM {table_name}) AS total_rows
        ) AS results;
    """
    start_time = time.time()
    cursor.execute(query)
    result = cursor.fetchone()
    execution_time = time.time() - start_time
    ratio = result[0] if result else 0

    return ratio, execution_time


# Completeness Ratio
def completeness_ratio(cursor, table_name, columns):
    if not columns:
        return 0

    cursor.execute(f"SELECT COUNT(*) FROM `{table_name}`;")
    total_counts = cursor.fetchone()[0]

    query = " AND ".join([f"`{col}` IS NOT NULL" for col in columns])
    cursor.execute(f"SELECT COUNT(*) FROM `{table_name}` WHERE {query};")
    non_null_count = cursor.fetchone()[0]

    return non_null_count/total_counts

# %% [markdown]
# # Show All Ratios in Tables

# %%
def main_ur(user, password, database, table_name, columns, host="localhost", port=3306):
    connection = None
    try:
        connection = mysql.connector.connect(user=user, password=password, database=database, host='localhost')
        
        if connection.is_connected():
            cursor = connection.cursor()
            all_combinations = [combo for length in range(1, len(columns) + 1) for combo in combinations(columns, length)]
            execution_times_by_length = {}
            detailed_output = []

            for perm in all_combinations:
                ur, exec_time = pmax_uniqueness_ratio_sql(cursor, table_name, perm)
                cr = completeness_ratio(cursor, table_name, perm)
                key = len(perm)
                
                if key in execution_times_by_length:
                    execution_times_by_length[key].append(exec_time)
                else:
                    execution_times_by_length[key] = [exec_time]
                detailed_output.append((perm, ur, cr, exec_time))
                    
            table = PrettyTable()
            table.field_names = ['Key', 'Uniqueness Ratio', 'Completeness Ratio', 'Running Time for UR']
        
            for perm, ur, cr, exec_time in detailed_output:
                table.add_row([', '.join(perm), f'{ur:.4f}', f'{cr:.4f}', f'{exec_time:.4f}'])
                # print(f"Columns: {', '.join(perm)} | Uniqueness Ratio: {ratio:.4f} | Time: {exec_time:.4f} seconds")
            print(table)

    except Error as e:
        print("Error:", e)
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# %%
# for key, values in l1.items():
#     print(f"Table: {key}\nColumns: {values}")
#     main_ur(user="root", password="yzh_20010315", database="hockey", table_name=key, columns=values)

for key, values in l1.items():
    print(f"Table: {key}\nColumns: {values}")
    main_ur(
        user=mysql_cfg["user"],
        password=mysql_cfg["password"],
        database=mysql_cfg["database"],
        table_name=key,
        columns=values,
        host=mysql_cfg["host"],
        port=mysql_cfg["port"],
    )
# Out:
# Table: abbrev
# Columns: ['Type', 'Code', 'Fullname']
# +----------------------+------------------+--------------------+---------------------+
# |         Key          | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +----------------------+------------------+--------------------+---------------------+
# |         Type         |      0.0000      |       1.0000       |        0.0007       |
# |         Code         |      0.6552      |       1.0000       |        0.0005       |
# |       Fullname       |      1.0000      |       1.0000       |        0.0010       |
# |      Type, Code      |      1.0000      |       1.0000       |        0.0008       |
# |    Type, Fullname    |      1.0000      |       1.0000       |        0.0009       |
# |    Code, Fullname    |      1.0000      |       1.0000       |        0.0008       |
# | Type, Code, Fullname |      1.0000      |       1.0000       |        0.0008       |
# +----------------------+------------------+--------------------+---------------------+
# Table: awardscoaches
# Columns: ['coachID', 'award', 'year', 'lgID']
# +----------------------------+------------------+--------------------+---------------------+
# |            Key             | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +----------------------------+------------------+--------------------+---------------------+
# |          coachID           |      0.4675      |       1.0000       |        0.0007       |
# |           award            |      0.0000      |       1.0000       |        0.0005       |
# |            year            |      0.4286      |       1.0000       |        0.0004       |
# |            lgID            |      0.0000      |       1.0000       |        0.0004       |
# |       coachID, award       |      0.5714      |       1.0000       |        0.0006       |
# |       coachID, year        |      1.0000      |       1.0000       |        0.0006       |
# |       coachID, lgID        |      0.4935      |       1.0000       |        0.0004       |
# |        award, year         |      1.0000      |       1.0000       |        0.0004       |
# |        award, lgID         |      0.0000      |       1.0000       |        0.0004       |
# |         year, lgID         |      0.5844      |       1.0000       |        0.0004       |
# |    coachID, award, year    |      1.0000      |       1.0000       |        0.0005       |
# |    coachID, award, lgID    |      0.5714      |       1.0000       |        0.0005       |
# |    coachID, year, lgID     |      1.0000      |       1.0000       |        0.0004       |
# |     award, year, lgID      |      1.0000      |       1.0000       |        0.0004       |
# | coachID, award, year, lgID |      1.0000      |       1.0000       |        0.0005       |
# +----------------------------+------------------+--------------------+---------------------+
# Table: awardsmisc
# Columns: ['name', 'ID', 'award', 'year', 'lgID']
# +-----------------------------+------------------+--------------------+---------------------+
# |             Key             | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +-----------------------------+------------------+--------------------+---------------------+
# |             name            |      1.0000      |       1.0000       |        0.0005       |
# |              ID             |      1.0000      |       0.6855       |        0.0003       |
# |            award            |      0.0000      |       1.0000       |        0.0003       |
# |             year            |      0.0565      |       1.0000       |        0.0003       |
# |             lgID            |      0.0000      |       1.0000       |        0.0003       |
# |           name, ID          |      1.0000      |       0.6855       |        0.0004       |
# |         name, award         |      1.0000      |       1.0000       |        0.0004       |
# |          name, year         |      1.0000      |       1.0000       |        0.0004       |
# |          name, lgID         |      1.0000      |       1.0000       |        0.0004       |
# |          ID, award          |      1.0000      |       0.6855       |        0.0004       |
# |           ID, year          |      1.0000      |       0.6855       |        0.0004       |
# |           ID, lgID          |      1.0000      |       0.6855       |        0.0004       |
# |         award, year         |      0.0565      |       1.0000       |        0.0003       |
# |         award, lgID         |      0.0000      |       1.0000       |        0.0003       |
# |          year, lgID         |      0.0565      |       1.0000       |        0.0004       |
# |       name, ID, award       |      1.0000      |       0.6855       |        0.0003       |
# |        name, ID, year       |      1.0000      |       0.6855       |        0.0003       |
# |        name, ID, lgID       |      1.0000      |       0.6855       |        0.0002       |
# |      name, award, year      |      1.0000      |       1.0000       |        0.0002       |
# |      name, award, lgID      |      1.0000      |       1.0000       |        0.0003       |
# |       name, year, lgID      |      1.0000      |       1.0000       |        0.0003       |
# |       ID, award, year       |      1.0000      |       0.6855       |        0.0002       |
# |       ID, award, lgID       |      1.0000      |       0.6855       |        0.0002       |
# |        ID, year, lgID       |      1.0000      |       0.6855       |        0.0002       |
# |      award, year, lgID      |      0.0565      |       1.0000       |        0.0002       |
# |    name, ID, award, year    |      1.0000      |       0.6855       |        0.0002       |
# |    name, ID, award, lgID    |      1.0000      |       0.6855       |        0.0003       |
# |     name, ID, year, lgID    |      1.0000      |       0.6855       |        0.0003       |
# |   name, award, year, lgID   |      1.0000      |       1.0000       |        0.0003       |
# |    ID, award, year, lgID    |      1.0000      |       0.6855       |        0.0003       |
# | name, ID, award, year, lgID |      1.0000      |       0.6855       |        0.0003       |
# +-----------------------------+------------------+--------------------+---------------------+
# Table: awardsplayers
# Columns: ['playerID', 'award', 'year', 'lgID', 'pos']
# +----------------------------------+------------------+--------------------+---------------------+
# |               Key                | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +----------------------------------+------------------+--------------------+---------------------+
# |             playerID             |      0.1468      |       1.0000       |        0.0010       |
# |              award               |      0.0000      |       1.0000       |        0.0013       |
# |               year               |      0.0029      |       1.0000       |        0.0007       |
# |               lgID               |      0.0000      |       1.0000       |        0.0012       |
# |               pos                |      0.4113      |       0.5887       |        0.0009       |
# |         playerID, award          |      0.4405      |       1.0000       |        0.0008       |
# |          playerID, year          |      0.5308      |       1.0000       |        0.0019       |
# |          playerID, lgID          |      0.1497      |       1.0000       |        0.0016       |
# |          playerID, pos           |      0.5562      |       0.5887       |        0.0013       |
# |           award, year            |      0.3725      |       1.0000       |        0.0013       |
# |           award, lgID            |      0.0000      |       1.0000       |        0.0025       |
# |            award, pos            |      0.4113      |       0.5887       |        0.0017       |
# |            year, lgID            |      0.0029      |       1.0000       |        0.0013       |
# |            year, pos             |      0.4113      |       0.5887       |        0.0011       |
# |            lgID, pos             |      0.4113      |       0.5887       |        0.0016       |
# |      playerID, award, year       |      1.0000      |       1.0000       |        0.0012       |
# |      playerID, award, lgID       |      0.4429      |       1.0000       |        0.0028       |
# |       playerID, award, pos       |      0.6351      |       0.5887       |        0.0020       |
# |       playerID, year, lgID       |      0.5308      |       1.0000       |        0.0021       |
# |       playerID, year, pos        |      0.9943      |       0.5887       |        0.0017       |
# |       playerID, lgID, pos        |      0.5571      |       0.5887       |        0.0017       |
# |        award, year, lgID         |      0.3725      |       1.0000       |        0.0021       |
# |         award, year, pos         |      0.7231      |       0.5887       |        0.0017       |
# |         award, lgID, pos         |      0.4113      |       0.5887       |        0.0017       |
# |         year, lgID, pos          |      0.4113      |       0.5887       |        0.0015       |
# |   playerID, award, year, lgID    |      1.0000      |       1.0000       |        0.0028       |
# |    playerID, award, year, pos    |      1.0000      |       0.5887       |        0.0020       |
# |    playerID, award, lgID, pos    |      0.6370      |       0.5887       |        0.0019       |
# |    playerID, year, lgID, pos     |      0.9943      |       0.5887       |        0.0018       |
# |      award, year, lgID, pos      |      0.7767      |       0.5887       |        0.0018       |
# | playerID, award, year, lgID, pos |      1.0000      |       0.5887       |        0.0018       |
# +----------------------------------+------------------+--------------------+---------------------+
# Table: coaches
# Columns: ['coachID', 'year', 'tmID', 'lgID', 'stint']
# +----------------------------------+------------------+--------------------+---------------------+
# |               Key                | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +----------------------------------+------------------+--------------------+---------------------+
# |             coachID              |      0.0585      |       1.0000       |        0.0006       |
# |               year               |      0.0000      |       1.0000       |        0.0005       |
# |               tmID               |      0.0105      |       1.0000       |        0.0007       |
# |               lgID               |      0.0000      |       1.0000       |        0.0009       |
# |              stint               |      0.0000      |       1.0000       |        0.0005       |
# |          coachID, year           |      0.9845      |       1.0000       |        0.0008       |
# |          coachID, tmID           |      0.1391      |       1.0000       |        0.0010       |
# |          coachID, lgID           |      0.0690      |       1.0000       |        0.0013       |
# |          coachID, stint          |      0.1325      |       1.0000       |        0.0009       |
# |            year, tmID            |      0.6909      |       1.0000       |        0.0006       |
# |            year, lgID            |      0.0000      |       1.0000       |        0.0011       |
# |           year, stint            |      0.0204      |       1.0000       |        0.0006       |
# |            tmID, lgID            |      0.0105      |       1.0000       |        0.0011       |
# |           tmID, stint            |      0.0315      |       1.0000       |        0.0008       |
# |           lgID, stint            |      0.0006      |       1.0000       |        0.0011       |
# |       coachID, year, tmID        |      0.9945      |       1.0000       |        0.0009       |
# |       coachID, year, lgID        |      0.9845      |       1.0000       |        0.0018       |
# |       coachID, year, stint       |      1.0000      |       1.0000       |        0.0012       |
# |       coachID, tmID, lgID        |      0.1391      |       1.0000       |        0.0016       |
# |       coachID, tmID, stint       |      0.2362      |       1.0000       |        0.0011       |
# |       coachID, lgID, stint       |      0.1440      |       1.0000       |        0.0014       |
# |         year, tmID, lgID         |      0.6909      |       1.0000       |        0.0016       |
# |        year, tmID, stint         |      0.9989      |       1.0000       |        0.0011       |
# |        year, lgID, stint         |      0.0215      |       1.0000       |        0.0012       |
# |        tmID, lgID, stint         |      0.0315      |       1.0000       |        0.0013       |
# |    coachID, year, tmID, lgID     |      0.9945      |       1.0000       |        0.0021       |
# |    coachID, year, tmID, stint    |      1.0000      |       1.0000       |        0.0009       |
# |    coachID, year, lgID, stint    |      1.0000      |       1.0000       |        0.0019       |
# |    coachID, tmID, lgID, stint    |      0.2362      |       1.0000       |        0.0018       |
# |     year, tmID, lgID, stint      |      0.9989      |       1.0000       |        0.0018       |
# | coachID, year, tmID, lgID, stint |      1.0000      |       1.0000       |        0.0022       |
# +----------------------------------+------------------+--------------------+---------------------+
# Table: combinedshutouts
# Columns: ['year', 'month', 'date', 'tmID', 'oppID', 'R/P', 'IDgoalie1', 'IDgoalie2']
# +-----------------------------------------------------------+------------------+--------------------+---------------------+
# |                            Key                            | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +-----------------------------------------------------------+------------------+--------------------+---------------------+
# |                            year                           |      0.3333      |       1.0000       |        0.0003       |
# |                           month                           |      0.0185      |       1.0000       |        0.0002       |
# |                            date                           |      0.1852      |       1.0000       |        0.0002       |
# |                            tmID                           |      0.2407      |       1.0000       |        0.0002       |
# |                           oppID                           |      0.2963      |       1.0000       |        0.0002       |
# |                            R/P                            |      0.0000      |       1.0000       |        0.0001       |
# |                         IDgoalie1                         |      0.6296      |       1.0000       |        0.0002       |
# |                         IDgoalie2                         |      0.7963      |       1.0000       |        0.0002       |
# |                        year, month                        |      0.8889      |       1.0000       |        0.0002       |
# |                         year, date                        |      1.0000      |       1.0000       |        0.0002       |
# |                         year, tmID                        |      0.8889      |       1.0000       |        0.0002       |
# |                        year, oppID                        |      1.0000      |       1.0000       |        0.0002       |
# |                         year, R/P                         |      0.3333      |       1.0000       |        0.0002       |
# |                      year, IDgoalie1                      |      0.8889      |       1.0000       |        0.0002       |
# |                      year, IDgoalie2                      |      0.9259      |       1.0000       |        0.0001       |
# |                        month, date                        |      0.8889      |       1.0000       |        0.0001       |
# |                        month, tmID                        |      0.7407      |       1.0000       |        0.0001       |
# |                        month, oppID                       |      0.8889      |       1.0000       |        0.0001       |
# |                         month, R/P                        |      0.0556      |       1.0000       |        0.0001       |
# |                      month, IDgoalie1                     |      0.9630      |       1.0000       |        0.0001       |
# |                      month, IDgoalie2                     |      0.9630      |       1.0000       |        0.0001       |
# |                         date, tmID                        |      1.0000      |       1.0000       |        0.0002       |
# |                        date, oppID                        |      0.8889      |       1.0000       |        0.0002       |
# |                         date, R/P                         |      0.2778      |       1.0000       |        0.0002       |
# |                      date, IDgoalie1                      |      1.0000      |       1.0000       |        0.0002       |
# |                      date, IDgoalie2                      |      1.0000      |       1.0000       |        0.0002       |
# |                        tmID, oppID                        |      0.9630      |       1.0000       |        0.0002       |
# |                         tmID, R/P                         |      0.2963      |       1.0000       |        0.0002       |
# |                      tmID, IDgoalie1                      |      0.7222      |       1.0000       |        0.0002       |
# |                      tmID, IDgoalie2                      |      0.9259      |       1.0000       |        0.0002       |
# |                         oppID, R/P                        |      0.3333      |       1.0000       |        0.0002       |
# |                      oppID, IDgoalie1                     |      0.9630      |       1.0000       |        0.0002       |
# |                      oppID, IDgoalie2                     |      1.0000      |       1.0000       |        0.0002       |
# |                       R/P, IDgoalie1                      |      0.6852      |       1.0000       |        0.0002       |
# |                       R/P, IDgoalie2                      |      0.8333      |       1.0000       |        0.0002       |
# |                    IDgoalie1, IDgoalie2                   |      0.9259      |       1.0000       |        0.0002       |
# |                     year, month, date                     |      1.0000      |       1.0000       |        0.0002       |
# |                     year, month, tmID                     |      1.0000      |       1.0000       |        0.0002       |
# |                     year, month, oppID                    |      1.0000      |       1.0000       |        0.0002       |
# |                      year, month, R/P                     |      0.8889      |       1.0000       |        0.0002       |
# |                   year, month, IDgoalie1                  |      1.0000      |       1.0000       |        0.0002       |
# |                   year, month, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                      year, date, tmID                     |      1.0000      |       1.0000       |        0.0002       |
# |                     year, date, oppID                     |      1.0000      |       1.0000       |        0.0002       |
# |                      year, date, R/P                      |      1.0000      |       1.0000       |        0.0002       |
# |                   year, date, IDgoalie1                   |      1.0000      |       1.0000       |        0.0002       |
# |                   year, date, IDgoalie2                   |      1.0000      |       1.0000       |        0.0002       |
# |                     year, tmID, oppID                     |      1.0000      |       1.0000       |        0.0002       |
# |                      year, tmID, R/P                      |      0.8889      |       1.0000       |        0.0002       |
# |                   year, tmID, IDgoalie1                   |      0.8889      |       1.0000       |        0.0002       |
# |                   year, tmID, IDgoalie2                   |      0.9259      |       1.0000       |        0.0002       |
# |                      year, oppID, R/P                     |      1.0000      |       1.0000       |        0.0002       |
# |                   year, oppID, IDgoalie1                  |      1.0000      |       1.0000       |        0.0002       |
# |                   year, oppID, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                    year, R/P, IDgoalie1                   |      0.8889      |       1.0000       |        0.0002       |
# |                    year, R/P, IDgoalie2                   |      0.9259      |       1.0000       |        0.0002       |
# |                 year, IDgoalie1, IDgoalie2                |      0.9259      |       1.0000       |        0.0002       |
# |                     month, date, tmID                     |      1.0000      |       1.0000       |        0.0002       |
# |                     month, date, oppID                    |      1.0000      |       1.0000       |        0.0002       |
# |                      month, date, R/P                     |      0.8889      |       1.0000       |        0.0001       |
# |                   month, date, IDgoalie1                  |      1.0000      |       1.0000       |        0.0002       |
# |                   month, date, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                     month, tmID, oppID                    |      1.0000      |       1.0000       |        0.0002       |
# |                      month, tmID, R/P                     |      0.7778      |       1.0000       |        0.0002       |
# |                   month, tmID, IDgoalie1                  |      1.0000      |       1.0000       |        0.0002       |
# |                   month, tmID, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                     month, oppID, R/P                     |      0.8889      |       1.0000       |        0.0001       |
# |                  month, oppID, IDgoalie1                  |      1.0000      |       1.0000       |        0.0002       |
# |                  month, oppID, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                   month, R/P, IDgoalie1                   |      1.0000      |       1.0000       |        0.0002       |
# |                   month, R/P, IDgoalie2                   |      0.9630      |       1.0000       |        0.0002       |
# |                month, IDgoalie1, IDgoalie2                |      1.0000      |       1.0000       |        0.0002       |
# |                     date, tmID, oppID                     |      1.0000      |       1.0000       |        0.0001       |
# |                      date, tmID, R/P                      |      1.0000      |       1.0000       |        0.0001       |
# |                   date, tmID, IDgoalie1                   |      1.0000      |       1.0000       |        0.0001       |
# |                   date, tmID, IDgoalie2                   |      1.0000      |       1.0000       |        0.0001       |
# |                      date, oppID, R/P                     |      0.8889      |       1.0000       |        0.0002       |
# |                   date, oppID, IDgoalie1                  |      1.0000      |       1.0000       |        0.0002       |
# |                   date, oppID, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                    date, R/P, IDgoalie1                   |      1.0000      |       1.0000       |        0.0002       |
# |                    date, R/P, IDgoalie2                   |      1.0000      |       1.0000       |        0.0002       |
# |                 date, IDgoalie1, IDgoalie2                |      1.0000      |       1.0000       |        0.0002       |
# |                      tmID, oppID, R/P                     |      0.9630      |       1.0000       |        0.0002       |
# |                   tmID, oppID, IDgoalie1                  |      0.9630      |       1.0000       |        0.0002       |
# |                   tmID, oppID, IDgoalie2                  |      1.0000      |       1.0000       |        0.0002       |
# |                    tmID, R/P, IDgoalie1                   |      0.7593      |       1.0000       |        0.0001       |
# |                    tmID, R/P, IDgoalie2                   |      0.9259      |       1.0000       |        0.0002       |
# |                 tmID, IDgoalie1, IDgoalie2                |      0.9259      |       1.0000       |        0.0002       |
# |                   oppID, R/P, IDgoalie1                   |      0.9630      |       1.0000       |        0.0002       |
# |                   oppID, R/P, IDgoalie2                   |      1.0000      |       1.0000       |        0.0002       |
# |                oppID, IDgoalie1, IDgoalie2                |      1.0000      |       1.0000       |        0.0002       |
# |                 R/P, IDgoalie1, IDgoalie2                 |      0.9259      |       1.0000       |        0.0002       |
# |                  year, month, date, tmID                  |      1.0000      |       1.0000       |        0.0001       |
# |                  year, month, date, oppID                 |      1.0000      |       1.0000       |        0.0001       |
# |                   year, month, date, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |                year, month, date, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |                year, month, date, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                  year, month, tmID, oppID                 |      1.0000      |       1.0000       |        0.0001       |
# |                   year, month, tmID, R/P                  |      1.0000      |       1.0000       |        0.0002       |
# |                year, month, tmID, IDgoalie1               |      1.0000      |       1.0000       |        0.0002       |
# |                year, month, tmID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                  year, month, oppID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |               year, month, oppID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |               year, month, oppID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                year, month, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0002       |
# |                year, month, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |             year, month, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0001       |
# |                  year, date, tmID, oppID                  |      1.0000      |       1.0000       |        0.0001       |
# |                   year, date, tmID, R/P                   |      1.0000      |       1.0000       |        0.0001       |
# |                year, date, tmID, IDgoalie1                |      1.0000      |       1.0000       |        0.0001       |
# |                year, date, tmID, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |                   year, date, oppID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |                year, date, oppID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |                year, date, oppID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                 year, date, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0001       |
# |                 year, date, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |              year, date, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0001       |
# |                   year, tmID, oppID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |                year, tmID, oppID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |                year, tmID, oppID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                 year, tmID, R/P, IDgoalie1                |      0.8889      |       1.0000       |        0.0002       |
# |                 year, tmID, R/P, IDgoalie2                |      0.9259      |       1.0000       |        0.0002       |
# |              year, tmID, IDgoalie1, IDgoalie2             |      0.9259      |       1.0000       |        0.0002       |
# |                year, oppID, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0001       |
# |                year, oppID, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |             year, oppID, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |              year, R/P, IDgoalie1, IDgoalie2              |      0.9259      |       1.0000       |        0.0002       |
# |                  month, date, tmID, oppID                 |      1.0000      |       1.0000       |        0.0001       |
# |                   month, date, tmID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |                month, date, tmID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |                month, date, tmID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                  month, date, oppID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |               month, date, oppID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |               month, date, oppID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                month, date, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0001       |
# |                month, date, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |             month, date, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |                  month, tmID, oppID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |               month, tmID, oppID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |               month, tmID, oppID, IDgoalie2               |      1.0000      |       1.0000       |        0.0002       |
# |                month, tmID, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0002       |
# |                month, tmID, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |             month, tmID, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |                month, oppID, R/P, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |                month, oppID, R/P, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |             month, oppID, IDgoalie1, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |              month, R/P, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0001       |
# |                   date, tmID, oppID, R/P                  |      1.0000      |       1.0000       |        0.0001       |
# |                date, tmID, oppID, IDgoalie1               |      1.0000      |       1.0000       |        0.0001       |
# |                date, tmID, oppID, IDgoalie2               |      1.0000      |       1.0000       |        0.0001       |
# |                 date, tmID, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0001       |
# |                 date, tmID, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |              date, tmID, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0001       |
# |                date, oppID, R/P, IDgoalie1                |      1.0000      |       1.0000       |        0.0001       |
# |                date, oppID, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |             date, oppID, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |              date, R/P, IDgoalie1, IDgoalie2              |      1.0000      |       1.0000       |        0.0001       |
# |                tmID, oppID, R/P, IDgoalie1                |      0.9630      |       1.0000       |        0.0002       |
# |                tmID, oppID, R/P, IDgoalie2                |      1.0000      |       1.0000       |        0.0001       |
# |             tmID, oppID, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |              tmID, R/P, IDgoalie1, IDgoalie2              |      0.9259      |       1.0000       |        0.0002       |
# |              oppID, R/P, IDgoalie1, IDgoalie2             |      1.0000      |       1.0000       |        0.0001       |
# |               year, month, date, tmID, oppID              |      1.0000      |       1.0000       |        0.0002       |
# |                year, month, date, tmID, R/P               |      1.0000      |       1.0000       |        0.0001       |
# |             year, month, date, tmID, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |             year, month, date, tmID, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |               year, month, date, oppID, R/P               |      1.0000      |       1.0000       |        0.0001       |
# |            year, month, date, oppID, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |            year, month, date, oppID, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |             year, month, date, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0001       |
# |             year, month, date, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, date, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0001       |
# |               year, month, tmID, oppID, R/P               |      1.0000      |       1.0000       |        0.0002       |
# |            year, month, tmID, oppID, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |            year, month, tmID, oppID, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |             year, month, tmID, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0002       |
# |             year, month, tmID, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, tmID, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |             year, month, oppID, R/P, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |             year, month, oppID, R/P, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, oppID, IDgoalie1, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |           year, month, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |                year, date, tmID, oppID, R/P               |      1.0000      |       1.0000       |        0.0001       |
# |             year, date, tmID, oppID, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |             year, date, tmID, oppID, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |              year, date, tmID, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0002       |
# |              year, date, tmID, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |           year, date, tmID, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |             year, date, oppID, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0002       |
# |             year, date, oppID, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |          year, date, oppID, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |           year, date, R/P, IDgoalie1, IDgoalie2           |      1.0000      |       1.0000       |        0.0002       |
# |             year, tmID, oppID, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0002       |
# |             year, tmID, oppID, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |          year, tmID, oppID, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |           year, tmID, R/P, IDgoalie1, IDgoalie2           |      0.9259      |       1.0000       |        0.0001       |
# |           year, oppID, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |               month, date, tmID, oppID, R/P               |      1.0000      |       1.0000       |        0.0001       |
# |            month, date, tmID, oppID, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |            month, date, tmID, oppID, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |             month, date, tmID, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0002       |
# |             month, date, tmID, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |          month, date, tmID, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |             month, date, oppID, R/P, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |             month, date, oppID, R/P, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |          month, date, oppID, IDgoalie1, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |           month, date, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |             month, tmID, oppID, R/P, IDgoalie1            |      1.0000      |       1.0000       |        0.0002       |
# |             month, tmID, oppID, R/P, IDgoalie2            |      1.0000      |       1.0000       |        0.0002       |
# |          month, tmID, oppID, IDgoalie1, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |           month, tmID, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |          month, oppID, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |             date, tmID, oppID, R/P, IDgoalie1             |      1.0000      |       1.0000       |        0.0002       |
# |             date, tmID, oppID, R/P, IDgoalie2             |      1.0000      |       1.0000       |        0.0002       |
# |          date, tmID, oppID, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |           date, tmID, R/P, IDgoalie1, IDgoalie2           |      1.0000      |       1.0000       |        0.0002       |
# |           date, oppID, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |           tmID, oppID, R/P, IDgoalie1, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |            year, month, date, tmID, oppID, R/P            |      1.0000      |       1.0000       |        0.0002       |
# |         year, month, date, tmID, oppID, IDgoalie1         |      1.0000      |       1.0000       |        0.0002       |
# |         year, month, date, tmID, oppID, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, date, tmID, R/P, IDgoalie1          |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, date, tmID, R/P, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |       year, month, date, tmID, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, date, oppID, R/P, IDgoalie1         |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, date, oppID, R/P, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |       year, month, date, oppID, IDgoalie1, IDgoalie2      |      1.0000      |       1.0000       |        0.0002       |
# |        year, month, date, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, tmID, oppID, R/P, IDgoalie1         |      1.0000      |       1.0000       |        0.0002       |
# |          year, month, tmID, oppID, R/P, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |       year, month, tmID, oppID, IDgoalie1, IDgoalie2      |      1.0000      |       1.0000       |        0.0002       |
# |        year, month, tmID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |       year, month, oppID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |          year, date, tmID, oppID, R/P, IDgoalie1          |      1.0000      |       1.0000       |        0.0002       |
# |          year, date, tmID, oppID, R/P, IDgoalie2          |      1.0000      |       1.0000       |        0.0002       |
# |       year, date, tmID, oppID, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |        year, date, tmID, R/P, IDgoalie1, IDgoalie2        |      1.0000      |       1.0000       |        0.0002       |
# |        year, date, oppID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |        year, tmID, oppID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |          month, date, tmID, oppID, R/P, IDgoalie1         |      1.0000      |       1.0000       |        0.0002       |
# |          month, date, tmID, oppID, R/P, IDgoalie2         |      1.0000      |       1.0000       |        0.0002       |
# |       month, date, tmID, oppID, IDgoalie1, IDgoalie2      |      1.0000      |       1.0000       |        0.0002       |
# |        month, date, tmID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |       month, date, oppID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |       month, tmID, oppID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |        date, tmID, oppID, R/P, IDgoalie1, IDgoalie2       |      1.0000      |       1.0000       |        0.0002       |
# |       year, month, date, tmID, oppID, R/P, IDgoalie1      |      1.0000      |       1.0000       |        0.0002       |
# |       year, month, date, tmID, oppID, R/P, IDgoalie2      |      1.0000      |       1.0000       |        0.0002       |
# |    year, month, date, tmID, oppID, IDgoalie1, IDgoalie2   |      1.0000      |       1.0000       |        0.0002       |
# |     year, month, date, tmID, R/P, IDgoalie1, IDgoalie2    |      1.0000      |       1.0000       |        0.0002       |
# |    year, month, date, oppID, R/P, IDgoalie1, IDgoalie2    |      1.0000      |       1.0000       |        0.0002       |
# |    year, month, tmID, oppID, R/P, IDgoalie1, IDgoalie2    |      1.0000      |       1.0000       |        0.0002       |
# |     year, date, tmID, oppID, R/P, IDgoalie1, IDgoalie2    |      1.0000      |       1.0000       |        0.0002       |
# |    month, date, tmID, oppID, R/P, IDgoalie1, IDgoalie2    |      1.0000      |       1.0000       |        0.0002       |
# | year, month, date, tmID, oppID, R/P, IDgoalie1, IDgoalie2 |      1.0000      |       1.0000       |        0.0003       |
# +-----------------------------------------------------------+------------------+--------------------+---------------------+
# Table: goalies
# Columns: ['playerID', 'year', 'stint', 'tmID', 'lgID', 'GP']
# +---------------------------------------+------------------+--------------------+---------------------+
# |                  Key                  | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +---------------------------------------+------------------+--------------------+---------------------+
# |                playerID               |      0.0535      |       1.0000       |        0.0014       |
# |                  year                 |      0.0000      |       1.0000       |        0.0009       |
# |                 stint                 |      0.0000      |       1.0000       |        0.0011       |
# |                  tmID                 |      0.0019      |       1.0000       |        0.0016       |
# |                  lgID                 |      0.0000      |       1.0000       |        0.0021       |
# |                   GP                  |      0.0054      |       0.9951       |        0.0020       |
# |             playerID, year            |      0.8899      |       1.0000       |        0.0015       |
# |            playerID, stint            |      0.0823      |       1.0000       |        0.0018       |
# |             playerID, tmID            |      0.1982      |       1.0000       |        0.0027       |
# |             playerID, lgID            |      0.0612      |       1.0000       |        0.0032       |
# |              playerID, GP             |      0.7910      |       0.9951       |        0.0036       |
# |              year, stint              |      0.0040      |       1.0000       |        0.0013       |
# |               year, tmID              |      0.0477      |       1.0000       |        0.0012       |
# |               year, lgID              |      0.0000      |       1.0000       |        0.0025       |
# |                year, GP               |      0.3424      |       0.9951       |        0.0030       |
# |              stint, tmID              |      0.0070      |       1.0000       |        0.0023       |
# |              stint, lgID              |      0.0007      |       1.0000       |        0.0027       |
# |               stint, GP               |      0.0091      |       0.9951       |        0.0024       |
# |               tmID, lgID              |      0.0019      |       1.0000       |        0.0027       |
# |                tmID, GP               |      0.2637      |       0.9951       |        0.0030       |
# ...
# |             year, tmID, confID, rank, name            |      1.0000      |       0.5938       |        0.0019       |
# |             year, tmID, divID, rank, name             |      1.0000      |       0.7709       |        0.0021       |
# |          year, franchID, confID, divID, rank          |      1.0000      |       0.5938       |        0.0014       |
# |          year, franchID, confID, divID, name          |      1.0000      |       0.5938       |        0.0016       |
# |           year, franchID, confID, rank, name          |      1.0000      |       0.5938       |        0.0016       |
# |           year, franchID, divID, rank, name           |      1.0000      |       0.7709       |        0.0020       |
# |            year, confID, divID, rank, name            |      1.0000      |       0.5938       |        0.0016       |
# |          lgID, tmID, franchID, confID, divID          |      0.4101      |       0.5938       |        0.0014       |
# |           lgID, tmID, franchID, confID, rank          |      0.4589      |       0.5938       |        0.0013       |
# |           lgID, tmID, franchID, confID, name          |      0.4082      |       0.5938       |        0.0015       |
# |           lgID, tmID, franchID, divID, rank           |      0.3614      |       0.7709       |        0.0014       |
# |           lgID, tmID, franchID, divID, name           |      0.2449      |       0.7709       |        0.0017       |
# |            lgID, tmID, franchID, rank, name           |      0.0994      |       1.0000       |        0.0018       |
# |            lgID, tmID, confID, divID, rank            |      0.4760      |       0.5938       |        0.0013       |
# |            lgID, tmID, confID, divID, name            |      0.4101      |       0.5938       |        0.0015       |
# |             lgID, tmID, confID, rank, name            |      0.4602      |       0.5938       |        0.0015       |
# |             lgID, tmID, divID, rank, name             |      0.3634      |       0.7709       |        0.0016       |
# |          lgID, franchID, confID, divID, rank          |      0.4720      |       0.5938       |        0.0014       |
# |          lgID, franchID, confID, divID, name          |      0.4101      |       0.5938       |        0.0016       |
# |           lgID, franchID, confID, rank, name          |      0.4602      |       0.5938       |        0.0015       |
# |           lgID, franchID, divID, rank, name           |      0.3634      |       0.7709       |        0.0018       |
# |            lgID, confID, divID, rank, name            |      0.4779      |       0.5938       |        0.0015       |
# |          tmID, franchID, confID, divID, rank          |      0.4760      |       0.5938       |        0.0014       |
# |          tmID, franchID, confID, divID, name          |      0.4101      |       0.5938       |        0.0015       |
# |           tmID, franchID, confID, rank, name          |      0.4602      |       0.5938       |        0.0015       |
# |           tmID, franchID, divID, rank, name           |      0.3634      |       0.7709       |        0.0017       |
# |            tmID, confID, divID, rank, name            |      0.4779      |       0.5938       |        0.0015       |
# |          franchID, confID, divID, rank, name          |      0.4779      |       0.5938       |        0.0015       |
# |       year, lgID, tmID, franchID, confID, divID       |      1.0000      |       0.5938       |        0.0016       |
# |        year, lgID, tmID, franchID, confID, rank       |      1.0000      |       0.5938       |        0.0015       |
# |        year, lgID, tmID, franchID, confID, name       |      1.0000      |       0.5938       |        0.0019       |
# |        year, lgID, tmID, franchID, divID, rank        |      1.0000      |       0.7709       |        0.0017       |
# |        year, lgID, tmID, franchID, divID, name        |      1.0000      |       0.7709       |        0.0020       |
# |         year, lgID, tmID, franchID, rank, name        |      1.0000      |       1.0000       |        0.0022       |
# |         year, lgID, tmID, confID, divID, rank         |      1.0000      |       0.5938       |        0.0015       |
# |         year, lgID, tmID, confID, divID, name         |      1.0000      |       0.5938       |        0.0018       |
# |          year, lgID, tmID, confID, rank, name         |      1.0000      |       0.5938       |        0.0016       |
# |          year, lgID, tmID, divID, rank, name          |      1.0000      |       0.7709       |        0.0019       |
# |       year, lgID, franchID, confID, divID, rank       |      1.0000      |       0.5938       |        0.0016       |
# |       year, lgID, franchID, confID, divID, name       |      1.0000      |       0.5938       |        0.0018       |
# |        year, lgID, franchID, confID, rank, name       |      1.0000      |       0.5938       |        0.0017       |
# |        year, lgID, franchID, divID, rank, name        |      1.0000      |       0.7709       |        0.0020       |
# |         year, lgID, confID, divID, rank, name         |      1.0000      |       0.5938       |        0.0016       |
# |       year, tmID, franchID, confID, divID, rank       |      1.0000      |       0.5938       |        0.0015       |
# |       year, tmID, franchID, confID, divID, name       |      1.0000      |       0.5938       |        0.0017       |
# |        year, tmID, franchID, confID, rank, name       |      1.0000      |       0.5938       |        0.0017       |
# |        year, tmID, franchID, divID, rank, name        |      1.0000      |       0.7709       |        0.0019       |
# |         year, tmID, confID, divID, rank, name         |      1.0000      |       0.5938       |        0.0017       |
# |       year, franchID, confID, divID, rank, name       |      1.0000      |       0.5938       |        0.0017       |
# |       lgID, tmID, franchID, confID, divID, rank       |      0.4760      |       0.5938       |        0.0015       |
# |       lgID, tmID, franchID, confID, divID, name       |      0.4101      |       0.5938       |        0.0017       |
# |        lgID, tmID, franchID, confID, rank, name       |      0.4602      |       0.5938       |        0.0016       |
# |        lgID, tmID, franchID, divID, rank, name        |      0.3634      |       0.7709       |        0.0020       |
# |         lgID, tmID, confID, divID, rank, name         |      0.4779      |       0.5938       |        0.0016       |
# |       lgID, franchID, confID, divID, rank, name       |      0.4779      |       0.5938       |        0.0017       |
# |       tmID, franchID, confID, divID, rank, name       |      0.4779      |       0.5938       |        0.0016       |
# |    year, lgID, tmID, franchID, confID, divID, rank    |      1.0000      |       0.5938       |        0.0018       |
# |    year, lgID, tmID, franchID, confID, divID, name    |      1.0000      |       0.5938       |        0.0018       |
# |     year, lgID, tmID, franchID, confID, rank, name    |      1.0000      |       0.5938       |        0.0018       |
# |     year, lgID, tmID, franchID, divID, rank, name     |      1.0000      |       0.7709       |        0.0021       |
# |      year, lgID, tmID, confID, divID, rank, name      |      1.0000      |       0.5938       |        0.0018       |
# |    year, lgID, franchID, confID, divID, rank, name    |      1.0000      |       0.5938       |        0.0018       |
# |    year, tmID, franchID, confID, divID, rank, name    |      1.0000      |       0.5938       |        0.0018       |
# |    lgID, tmID, franchID, confID, divID, rank, name    |      0.4779      |       0.5938       |        0.0017       |
# | year, lgID, tmID, franchID, confID, divID, rank, name |      1.0000      |       0.5938       |        0.0019       |
# +-------------------------------------------------------+------------------+--------------------+---------------------+
# Table: teamshalf
# Columns: ['year', 'lgID', 'tmID', 'half', 'rank']
# +------------------------------+------------------+--------------------+---------------------+
# |             Key              | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +------------------------------+------------------+--------------------+---------------------+
# |             year             |      0.0000      |       1.0000       |        0.0002       |
# |             lgID             |      0.0000      |       1.0000       |        0.0002       |
# |             tmID             |      0.0244      |       1.0000       |        0.0001       |
# |             half             |      0.0000      |       1.0000       |        0.0001       |
# |             rank             |      0.0000      |       1.0000       |        0.0001       |
# |          year, lgID          |      0.0000      |       1.0000       |        0.0002       |
# |          year, tmID          |      0.0244      |       1.0000       |        0.0001       |
# |          year, half          |      0.0000      |       1.0000       |        0.0001       |
# |          year, rank          |      0.0244      |       1.0000       |        0.0001       |
# |          lgID, tmID          |      0.0244      |       1.0000       |        0.0002       |
# |          lgID, half          |      0.0000      |       1.0000       |        0.0001       |
# |          lgID, rank          |      0.0000      |       1.0000       |        0.0001       |
# |          tmID, half          |      0.4146      |       1.0000       |        0.0001       |
# |          tmID, rank          |      0.4146      |       1.0000       |        0.0002       |
# |          half, rank          |      0.0976      |       1.0000       |        0.0001       |
# |       year, lgID, tmID       |      0.0244      |       1.0000       |        0.0002       |
# |       year, lgID, half       |      0.0000      |       1.0000       |        0.0002       |
# |       year, lgID, rank       |      0.0244      |       1.0000       |        0.0002       |
# |       year, tmID, half       |      1.0000      |       1.0000       |        0.0001       |
# |       year, tmID, rank       |      0.8049      |       1.0000       |        0.0002       |
# |       year, half, rank       |      1.0000      |       1.0000       |        0.0002       |
# |       lgID, tmID, half       |      0.4146      |       1.0000       |        0.0002       |
# |       lgID, tmID, rank       |      0.4146      |       1.0000       |        0.0001       |
# |       lgID, half, rank       |      0.2927      |       1.0000       |        0.0001       |
# |       tmID, half, rank       |      0.7561      |       1.0000       |        0.0002       |
# |    year, lgID, tmID, half    |      1.0000      |       1.0000       |        0.0002       |
# |    year, lgID, tmID, rank    |      0.8049      |       1.0000       |        0.0002       |
# |    year, lgID, half, rank    |      1.0000      |       1.0000       |        0.0001       |
# |    year, tmID, half, rank    |      1.0000      |       1.0000       |        0.0001       |
# |    lgID, tmID, half, rank    |      0.7561      |       1.0000       |        0.0001       |
# | year, lgID, tmID, half, rank |      1.0000      |       1.0000       |        0.0001       |
# +------------------------------+------------------+--------------------+---------------------+
# Table: teamsplits
# Columns: ['year', 'lgID', 'tmID']
# +------------------+------------------+--------------------+---------------------+
# |       Key        | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +------------------+------------------+--------------------+---------------------+
# |       year       |      0.0000      |       1.0000       |        0.0004       |
# |       lgID       |      0.0000      |       1.0000       |        0.0009       |
# |       tmID       |      0.0158      |       1.0000       |        0.0005       |
# |    year, lgID    |      0.0000      |       1.0000       |        0.0010       |
# |    year, tmID    |      1.0000      |       1.0000       |        0.0007       |
# |    lgID, tmID    |      0.0158      |       1.0000       |        0.0011       |
# | year, lgID, tmID |      1.0000      |       1.0000       |        0.0015       |
# +------------------+------------------+--------------------+---------------------+
# Table: teamspost
# Columns: ['year', 'lgID', 'tmID']
# +------------------+------------------+--------------------+---------------------+
# |       Key        | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +------------------+------------------+--------------------+---------------------+
# |       year       |      0.0000      |       1.0000       |        0.0003       |
# |       lgID       |      0.0000      |       1.0000       |        0.0005       |
# |       tmID       |      0.0162      |       1.0000       |        0.0004       |
# |    year, lgID    |      0.0000      |       1.0000       |        0.0006       |
# |    year, tmID    |      1.0000      |       1.0000       |        0.0004       |
# |    lgID, tmID    |      0.0162      |       1.0000       |        0.0006       |
# | year, lgID, tmID |      1.0000      |       1.0000       |        0.0008       |
# +------------------+------------------+--------------------+---------------------+
# Table: teamssc
# Columns: ['year', 'lgID', 'tmID']
# +------------------+------------------+--------------------+---------------------+
# |       Key        | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +------------------+------------------+--------------------+---------------------+
# |       year       |      0.0000      |       1.0000       |        0.0002       |
# |       lgID       |      0.0000      |       1.0000       |        0.0002       |
# |       tmID       |      0.3000      |       1.0000       |        0.0001       |
# |    year, lgID    |      1.0000      |       1.0000       |        0.0001       |
# |    year, tmID    |      1.0000      |       1.0000       |        0.0001       |
# |    lgID, tmID    |      0.3000      |       1.0000       |        0.0001       |
# | year, lgID, tmID |      1.0000      |       1.0000       |        0.0001       |
# +------------------+------------------+--------------------+---------------------+
# Table: teamvsteam
# Columns: ['year', 'lgID', 'tmID', 'oppID']
# +-------------------------+------------------+--------------------+---------------------+
# |           Key           | Uniqueness Ratio | Completeness Ratio | Running Time for UR |
# +-------------------------+------------------+--------------------+---------------------+
# |           year          |      0.0000      |       1.0000       |        0.0043       |
# |           lgID          |      0.0000      |       1.0000       |        0.0117       |
# |           tmID          |      0.0000      |       1.0000       |        0.0082       |
# |          oppID          |      0.0000      |       1.0000       |        0.0047       |
# |        year, lgID       |      0.0000      |       1.0000       |        0.0135       |
# |        year, tmID       |      0.0000      |       1.0000       |        0.0056       |
# |       year, oppID       |      0.0000      |       1.0000       |        0.0100       |
# |        lgID, tmID       |      0.0000      |       1.0000       |        0.0147       |
# |       lgID, oppID       |      0.0000      |       1.0000       |        0.0144       |
# |       tmID, oppID       |      0.0178      |       1.0000       |        0.0109       |
# |     year, lgID, tmID    |      0.0000      |       1.0000       |        0.0170       |
# |    year, lgID, oppID    |      0.0000      |       1.0000       |        0.0167       |
# |    year, tmID, oppID    |      1.0000      |       1.0000       |        0.0111       |
# |    lgID, tmID, oppID    |      0.0178      |       1.0000       |        0.0198       |
# | year, lgID, tmID, oppID |      1.0000      |       1.0000       |        0.0293       |
# +-------------------------+------------------+--------------------+---------------------+

# %% [markdown]
# # MAX Ratio / MIN Ratio / AVERAGE Ratio

# %%
import matplotlib.pyplot as plt

def calculation(user, password, database, table_name, columns):
    try:
        connection = mysql.connector.connect(user=user, password=password, database=database)

        if connection.is_connected():
            cursor = connection.cursor()
            # columns = get_column_names(cursor, table_name)
            all_combinations = [combo for length in range(1, len(columns)+1) for combo in
                                combinations(columns, length)]
            execution_times_by_length = {}
            detailed_output = {}

            # Calculate the uniqueness ratio for each column combination
            for perm in all_combinations:
                ur, exec_time = pmax_uniqueness_ratio_sql(cursor, table_name, perm)
                cr = completeness_ratio(cursor, table_name, perm)
                
                key = len(perm)

                if key in execution_times_by_length:
                    execution_times_by_length[key].append(exec_time)
                    detailed_output[key].append((perm, ur, cr, exec_time))
                else:
                    execution_times_by_length[key] = [exec_time]
                    detailed_output[key] = [(perm, ur, cr, exec_time)]

            # Calculate average execution time by length of column combination
            avg_times = []
            lengths = []
            for length, times in sorted(execution_times_by_length.items()):
                avg_time = sum(times) / len(times)
                avg_times.append(avg_time)
                lengths.append(length)

    except Error as e:
        print("Error:", e)
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

    return detailed_output, avg_times, lengths

def plt_box(database, table_name, columns):
    detailed_output, avg_times, lengths = calculation('root', 'yzh_20010315', database, table_name, columns)

    # Convert uniqueness ratio in detailed output from Decimal to float type.
    # The value in uniqueness_ratios_by_length stores the number of column combinations and the uniqueness ratio, without specifying which column. This is useful for drawing box plots later.
    uniqueness_ratios_by_length = {}
    for key, values in detailed_output.items():
        if key not in uniqueness_ratios_by_length:
            uniqueness_ratios_by_length[key] = []
        uniqueness_ratios_by_length[key].extend([float(entry[1]) for entry in values])
    
    
    # print("Decimal: ", detailed_output)
    # print("Float: ", uniqueness_ratios_by_length)
    
    lengths = sorted(uniqueness_ratios_by_length.keys())
    ratio_lists = [uniqueness_ratios_by_length[l] for l in lengths]
    
    fig, ax = plt.subplots()
    box = ax.boxplot(ratio_lists, labels=[str(length) for length in lengths], whis=[0, 100])

    ax.set_xlabel('Size of Column Set')
    ax.set_ylabel('Maximum Uniqueness Ratio')
    ax.set_title(f'Maximum Uniqueness Ratio Distribution of {table_name}')
    
    # Annotate each box plot with the maximum, minimum, and median values
    for i, line in enumerate(box['whiskers']):
        # The Whiskers in the returned list are in groups of two, representing the lower and upper bounds respectively.
        x, y = line.get_xydata()[1]
        if i % 2 == 0: 
            ax.annotate(f'{y:.4f}', xy=(x, y), xytext=(-20, -10), textcoords='offset points', ha='left', va='baseline', color = 'blue')
        else:
            ax.annotate(f'{y:.4f}', xy=(x, y), xytext=(-20, 10), textcoords='offset points', ha='left', va='baseline', color = 'red')

    for i, line in enumerate(box['medians']):
        x, y = line.get_xydata()[1]
        ax.annotate(f'{y:.4f}', xy=(x, y), xytext=(-20, 0), textcoords='offset points', ha='center', va='baseline', color='orange')

    plt.show()

# %%
def plt_box2(database, table_name, columns):
    detailed_output, avg_times, lengths = calculation('root', 'yzh_20010315', database, table_name, columns)

    uniqueness_ratios_by_length = {}
    for key, values in detailed_output.items():
        if key not in uniqueness_ratios_by_length:
            uniqueness_ratios_by_length[key] = []
        uniqueness_ratios_by_length[key].extend([float(entry[1]) for entry in values])

    lengths = sorted(uniqueness_ratios_by_length.keys())
    ratio_lists = [uniqueness_ratios_by_length[l] for l in lengths]
    
    fig, ax = plt.subplots(figsize=(10, 6))
    box = ax.boxplot(ratio_lists, labels=[str(length) for length in lengths], whis=[0, 100], showmeans=True)

    ax.set_xlabel('Size of Column Set')
    ax.set_ylabel('Maximum Uniqueness Ratio')
    ax.set_title(f'Maximum Uniqueness Ratio Distribution of {table_name}')
    
    for i, length in enumerate(lengths):
        q1 = box['boxes'][i].get_ydata()[1]
        q3 = box['boxes'][i].get_ydata()[2]
        median = box['medians'][i].get_ydata()[1]
        lower_whisker = box['whiskers'][2*i].get_ydata()[1]
        upper_whisker = box['whiskers'][2*i+1].get_ydata()[1]
    
        offset = 15 if i % 2 == 0 else -15
    
        ax.annotate(f'Q1: {q1:.4f}', xy=(i+1, q1), xytext=(-40, offset), textcoords='offset points', ha='right', va='center', color='orange')
        ax.annotate(f'Q3: {q3:.4f}', xy=(i+1, q3), xytext=(-40, -offset), textcoords='offset points', ha='right', va='center', color='orange')
        ax.annotate(f'Median: {median:.4f}', xy=(i+1, median), xytext=(-40, offset), textcoords='offset points', ha='right', va='center', color='green')
    
        ax.annotate(f'Max: {upper_whisker:.4f}', xy=(i+1, upper_whisker), xytext=(20, offset), textcoords='offset points', ha='left', va='center', color='red')
        ax.annotate(f'Min: {lower_whisker:.4f}', xy=(i+1, lower_whisker), xytext=(20, -offset), textcoords='offset points', ha='left', va='center', color='blue')


    plt.tight_layout()
    plt.show()

# %%
for key, values in l1.items():
    print(f"Table: {key}\nColumns: {values}")
    plt_box(database="hockey", table_name=key, columns=values)
# Out:
# Table: abbrev
# Columns: ['Type', 'Code', 'Fullname']
# Table: awardscoaches
# Columns: ['coachID', 'award', 'year', 'lgID']
# Table: awardsmisc
# Columns: ['name', 'ID', 'award', 'year', 'lgID']
# Table: awardsplayers
# Columns: ['playerID', 'award', 'year', 'lgID', 'pos']
# Table: coaches
# Columns: ['coachID', 'year', 'tmID', 'lgID', 'stint']
# Table: combinedshutouts
# Columns: ['year', 'month', 'date', 'tmID', 'oppID', 'R/P', 'IDgoalie1', 'IDgoalie2']
# Table: goalies
# Columns: ['playerID', 'year', 'stint', 'tmID', 'lgID', 'GP']
# Table: goaliessc
# Columns: ['playerID', 'year', 'tmID', 'lgID', 'GP']
# Table: goaliesshootout
# Columns: ['playerID', 'year', 'stint', 'tmID']
# Table: hof
# Columns: ['year', 'hofID', 'name', 'category']
# Table: master
# Columns: ['playerID', 'coachID', 'hofID', 'legendsID', 'ihdbID', 'hrefID', 'lastName', 'nameGiven', 'birthYear', 'pos']
# Table: scoring
# Columns: ['playerID', 'year', 'stint', 'tmID', 'lgID', 'pos']
# Table: scoringsc
# Columns: ['playerID', 'year', 'tmID', 'lgID', 'pos']
# Table: scoringshootout
# Columns: ['playerID', 'year', 'stint', 'tmID']
# Table: scoringsup
# Columns: ['playerID', 'year']
# Table: seriespost
# Columns: ['year', 'round', 'series', 'tmIDWinner', 'lgIDWinner', 'tmIDLoser', 'lgIDLoser']
# Table: teams
# Columns: ['year', 'lgID', 'tmID', 'franchID', 'confID', 'divID', 'rank', 'name']
# Table: teamshalf
# Columns: ['year', 'lgID', 'tmID', 'half', 'rank']
# Table: teamsplits
# Columns: ['year', 'lgID', 'tmID']
# Table: teamspost
# Columns: ['year', 'lgID', 'tmID']
# Table: teamssc
# Columns: ['year', 'lgID', 'tmID']
# Table: teamvsteam
# Columns: ['year', 'lgID', 'tmID', 'oppID']

# %% [markdown]
# # Top-5 keys table

# %%
from itertools import chain, combinations

def get_subkeys(key):
    subkeys = chain.from_iterable(combinations(key, r) for r in range(1, len(key)+1))
    return set(subkeys)

def top_5_keys(database, table_name, columns):
    global lengths, avg_times
    total_time = []
    table_data = []

    detailed_output, avg_times, lengths = calculation('root', 'yzh_20010315', database, table_name, columns)
    total_time.append(avg_times)

    # Convert all Decimal to float
    for level, entries in detailed_output.items():
        for idx, (column_combo, ur, cr,  time) in enumerate(entries):
            entries[idx] = (column_combo, float(ur), float(cr), time)

    # # Sort entries within each level by uniqueness ratio in descending order
    sorted_output = [(level, sorted(entries, key=lambda x: x[1], reverse=True)) for level, entries in detailed_output.items()]
    # print(sorted_output)

    # To remember which elements to exclude in future checks
    excluded_elements = set()
    # Processing each level
    
    nk = [] # Store data with ur >= 95%
    for level, entries in sorted_output:
        # Filter entries to exclude any tuple that contains elements from the excluded_elements set
        top_five_ratios = sorted(set([entry[1] for entry in entries]), reverse=True)[:5]
        filtered_entries = []
        for entry in entries:
            subkeys = get_subkeys(entry[0])
            # if entry[1] in top_five_ratios and entry[1] >= 0.95 and not subkeys.intersection(excluded_elements):
            if entry[1] in top_five_ratios and not subkeys.intersection(excluded_elements):
                filtered_entries.append(entry)

        # Updating the excluded elements if any tuple has a uniqueness ratio of 1.0
        
        for combo, ur, cr, exec_time in filtered_entries:
            if ur == 1.0:
                excluded_elements.add(combo)
            if ur > 0.95:
                nk.append([combo, ur, cr])
                
        # Prepare the table data entry
        # Select the top 5 or less if fewer entries available
        table_data.append((level, [(combo, ur, cr, exec_time) for combo, ur, cr, exec_time in filtered_entries]))

    # Print or process table_data as needed
    
    for entry in table_data:
        if len(entry[1]) != 0:
            print(f"Column Count: {entry[0]}")
            table = PrettyTable()
            table.field_names = ["Top-5 Keys", "UR", "CR", "Time"]
            for combo, ur, cr, exec_time in entry[1]:
                table.add_row([', '.join(combo), f'{ur:.4f}', f'{cr:.4f}', f'{exec_time:.4f}'])
                # print(f"{', '.join(combo)} & {ur:.4} \\\\")
            print(table)
            print()
            
    print("Near-Keys (UR >= 95%): ")
    table2 = PrettyTable()
    table2.field_names = ["Keys", "UR", "CR"]
    

    for n in nk:
        table2.add_row([', '.join(c for c in n[0]), f'{n[1]:.4f}', f'{n[2]:.4f}'])
    print(table2)
    
    return nk

# %%
nk_dic = {}
for key, values in l1.items():
    print("---------------------------------------------------------------------------------------------------------\n")
    print(f"Table: {key}\nColumns: {values}\n")
    nks = top_5_keys(database="hockey", table_name=key, columns=values)
    nk_dic[key] = nks
# Out:
# ---------------------------------------------------------------------------------------------------------
#
# Table: abbrev
# Columns: ['Type', 'Code', 'Fullname']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  Fullname  | 1.0000 | 1.0000 | 0.0004 |
# |    Code    | 0.6552 | 1.0000 | 0.0004 |
# |    Type    | 0.0000 | 1.0000 | 0.0007 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# | Type, Code | 1.0000 | 1.0000 | 0.0008 |
# +------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +------------+--------+--------+
# |    Keys    |   UR   |   CR   |
# +------------+--------+--------+
# |  Fullname  | 1.0000 | 1.0000 |
# | Type, Code | 1.0000 | 1.0000 |
# +------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: awardscoaches
# Columns: ['coachID', 'award', 'year', 'lgID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  coachID   | 0.4675 | 1.0000 | 0.0007 |
# |    year    | 0.4286 | 1.0000 | 0.0004 |
# |   award    | 0.0000 | 1.0000 | 0.0003 |
# |    lgID    | 0.0000 | 1.0000 | 0.0004 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# | coachID, year  | 1.0000 | 1.0000 | 0.0003 |
# |  award, year   | 1.0000 | 1.0000 | 0.0004 |
# |   year, lgID   | 0.5844 | 1.0000 | 0.0004 |
# | coachID, award | 0.5714 | 1.0000 | 0.0006 |
# | coachID, lgID  | 0.4935 | 1.0000 | 0.0003 |
# |  award, lgID   | 0.0000 | 1.0000 | 0.0004 |
# +----------------+--------+--------+--------+
#
# Column Count: 3
# +----------------------+--------+--------+--------+
# |      Top-5 Keys      |   UR   |   CR   |  Time  |
# +----------------------+--------+--------+--------+
# | coachID, award, lgID | 0.5714 | 1.0000 | 0.0005 |
# +----------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +---------------+--------+--------+
# |      Keys     |   UR   |   CR   |
# +---------------+--------+--------+
# | coachID, year | 1.0000 | 1.0000 |
# |  award, year  | 1.0000 | 1.0000 |
# +---------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: awardsmisc
# Columns: ['name', 'ID', 'award', 'year', 'lgID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    name    | 1.0000 | 1.0000 | 0.0006 |
# |     ID     | 1.0000 | 0.6855 | 0.0003 |
# |    year    | 0.0565 | 1.0000 | 0.0003 |
# |   award    | 0.0000 | 1.0000 | 0.0004 |
# |    lgID    | 0.0000 | 1.0000 | 0.0003 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-------------+--------+--------+--------+
# |  Top-5 Keys |   UR   |   CR   |  Time  |
# +-------------+--------+--------+--------+
# | award, year | 0.0565 | 1.0000 | 0.0003 |
# |  year, lgID | 0.0565 | 1.0000 | 0.0003 |
# | award, lgID | 0.0000 | 1.0000 | 0.0004 |
# +-------------+--------+--------+--------+
#
# Column Count: 3
# +-------------------+--------+--------+--------+
# |     Top-5 Keys    |   UR   |   CR   |  Time  |
# +-------------------+--------+--------+--------+
# | award, year, lgID | 0.0565 | 1.0000 | 0.0003 |
# +-------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +------+--------+--------+
# | Keys |   UR   |   CR   |
# +------+--------+--------+
# | name | 1.0000 | 1.0000 |
# |  ID  | 1.0000 | 0.6855 |
# +------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: awardsplayers
# Columns: ['playerID', 'award', 'year', 'lgID', 'pos']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    pos     | 0.4113 | 0.5887 | 0.0010 |
# |  playerID  | 0.1468 | 1.0000 | 0.0008 |
# |    year    | 0.0029 | 1.0000 | 0.0007 |
# |   award    | 0.0000 | 1.0000 | 0.0010 |
# |    lgID    | 0.0000 | 1.0000 | 0.0011 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-----------------+--------+--------+--------+
# |    Top-5 Keys   |   UR   |   CR   |  Time  |
# +-----------------+--------+--------+--------+
# |  playerID, pos  | 0.5562 | 0.5887 | 0.0013 |
# |  playerID, year | 0.5308 | 1.0000 | 0.0013 |
# | playerID, award | 0.4405 | 1.0000 | 0.0009 |
# |    award, pos   | 0.4113 | 0.5887 | 0.0013 |
# |    year, pos    | 0.4113 | 0.5887 | 0.0011 |
# |    lgID, pos    | 0.4113 | 0.5887 | 0.0012 |
# |   award, year   | 0.3725 | 1.0000 | 0.0013 |
# +-----------------+--------+--------+--------+
#
# Column Count: 3
# +-----------------------+--------+--------+--------+
# |       Top-5 Keys      |   UR   |   CR   |  Time  |
# +-----------------------+--------+--------+--------+
# | playerID, award, year | 1.0000 | 1.0000 | 0.0011 |
# |  playerID, year, pos  | 0.9943 | 0.5887 | 0.0015 |
# |    award, year, pos   | 0.7231 | 0.5887 | 0.0017 |
# |  playerID, award, pos | 0.6351 | 0.5887 | 0.0015 |
# |  playerID, lgID, pos  | 0.5571 | 0.5887 | 0.0014 |
# +-----------------------+--------+--------+--------+
#
# Column Count: 4
# +----------------------------+--------+--------+--------+
# |         Top-5 Keys         |   UR   |   CR   |  Time  |
# +----------------------------+--------+--------+--------+
# | playerID, year, lgID, pos  | 0.9943 | 0.5887 | 0.0019 |
# |   award, year, lgID, pos   | 0.7767 | 0.5887 | 0.0020 |
# | playerID, award, lgID, pos | 0.6370 | 0.5887 | 0.0019 |
# +----------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +---------------------------+--------+--------+
# |            Keys           |   UR   |   CR   |
# +---------------------------+--------+--------+
# |   playerID, award, year   | 1.0000 | 1.0000 |
# |    playerID, year, pos    | 0.9943 | 0.5887 |
# | playerID, year, lgID, pos | 0.9943 | 0.5887 |
# +---------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: coaches
# Columns: ['coachID', 'year', 'tmID', 'lgID', 'stint']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  coachID   | 0.0585 | 1.0000 | 0.0006 |
# |    tmID    | 0.0105 | 1.0000 | 0.0007 |
# |    year    | 0.0000 | 1.0000 | 0.0005 |
# |    lgID    | 0.0000 | 1.0000 | 0.0009 |
# |   stint    | 0.0000 | 1.0000 | 0.0006 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# | coachID, year  | 0.9845 | 1.0000 | 0.0008 |
# |   year, tmID   | 0.6909 | 1.0000 | 0.0007 |
# | coachID, tmID  | 0.1391 | 1.0000 | 0.0010 |
# | coachID, stint | 0.1325 | 1.0000 | 0.0009 |
# | coachID, lgID  | 0.0690 | 1.0000 | 0.0013 |
# +----------------+--------+--------+--------+
#
# Column Count: 3
# +----------------------+--------+--------+--------+
# |      Top-5 Keys      |   UR   |   CR   |  Time  |
# +----------------------+--------+--------+--------+
# | coachID, year, stint | 1.0000 | 1.0000 | 0.0013 |
# |  year, tmID, stint   | 0.9989 | 1.0000 | 0.0012 |
# | coachID, year, tmID  | 0.9945 | 1.0000 | 0.0009 |
# | coachID, year, lgID  | 0.9845 | 1.0000 | 0.0018 |
# |   year, tmID, lgID   | 0.6909 | 1.0000 | 0.0016 |
# +----------------------+--------+--------+--------+
#
# Column Count: 4
# +----------------------------+--------+--------+--------+
# |         Top-5 Keys         |   UR   |   CR   |  Time  |
# +----------------------------+--------+--------+--------+
# |  year, tmID, lgID, stint   | 0.9989 | 1.0000 | 0.0018 |
# | coachID, year, tmID, lgID  | 0.9945 | 1.0000 | 0.0021 |
# | coachID, tmID, lgID, stint | 0.2362 | 1.0000 | 0.0017 |
# +----------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +---------------------------+--------+--------+
# |            Keys           |   UR   |   CR   |
# +---------------------------+--------+--------+
# |       coachID, year       | 0.9845 | 1.0000 |
# |    coachID, year, stint   | 1.0000 | 1.0000 |
# |     year, tmID, stint     | 0.9989 | 1.0000 |
# |    coachID, year, tmID    | 0.9945 | 1.0000 |
# |    coachID, year, lgID    | 0.9845 | 1.0000 |
# |  year, tmID, lgID, stint  | 0.9989 | 1.0000 |
# | coachID, year, tmID, lgID | 0.9945 | 1.0000 |
# +---------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: combinedshutouts
# Columns: ['year', 'month', 'date', 'tmID', 'oppID', 'R/P', 'IDgoalie1', 'IDgoalie2']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# | IDgoalie2  | 0.7963 | 1.0000 | 0.0002 |
# | IDgoalie1  | 0.6296 | 1.0000 | 0.0002 |
# |    year    | 0.3333 | 1.0000 | 0.0002 |
# |   oppID    | 0.2963 | 1.0000 | 0.0002 |
# |    tmID    | 0.2407 | 1.0000 | 0.0002 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------------+--------+--------+--------+
# |      Top-5 Keys      |   UR   |   CR   |  Time  |
# +----------------------+--------+--------+--------+
# |      year, date      | 1.0000 | 1.0000 | 0.0002 |
# |     year, oppID      | 1.0000 | 1.0000 | 0.0002 |
# |      date, tmID      | 1.0000 | 1.0000 | 0.0002 |
# |   date, IDgoalie1    | 1.0000 | 1.0000 | 0.0002 |
# |   date, IDgoalie2    | 1.0000 | 1.0000 | 0.0001 |
# |   oppID, IDgoalie2   | 1.0000 | 1.0000 | 0.0001 |
# |   month, IDgoalie1   | 0.9630 | 1.0000 | 0.0002 |
# |   month, IDgoalie2   | 0.9630 | 1.0000 | 0.0002 |
# |     tmID, oppID      | 0.9630 | 1.0000 | 0.0001 |
# |   oppID, IDgoalie1   | 0.9630 | 1.0000 | 0.0002 |
# |   year, IDgoalie2    | 0.9259 | 1.0000 | 0.0002 |
# |   tmID, IDgoalie2    | 0.9259 | 1.0000 | 0.0001 |
# | IDgoalie1, IDgoalie2 | 0.9259 | 1.0000 | 0.0002 |
# |     year, month      | 0.8889 | 1.0000 | 0.0002 |
# |      year, tmID      | 0.8889 | 1.0000 | 0.0002 |
# |   year, IDgoalie1    | 0.8889 | 1.0000 | 0.0002 |
# |     month, date      | 0.8889 | 1.0000 | 0.0002 |
# |     month, oppID     | 0.8889 | 1.0000 | 0.0002 |
# |     date, oppID      | 0.8889 | 1.0000 | 0.0002 |
# |    R/P, IDgoalie2    | 0.8333 | 1.0000 | 0.0001 |
# +----------------------+--------+--------+--------+
#
# Column Count: 3
# +-----------------------------+--------+--------+--------+
# |          Top-5 Keys         |   UR   |   CR   |  Time  |
# +-----------------------------+--------+--------+--------+
# |      year, month, tmID      | 1.0000 | 1.0000 | 0.0002 |
# |    year, month, IDgoalie1   | 1.0000 | 1.0000 | 0.0002 |
# |    year, month, IDgoalie2   | 1.0000 | 1.0000 | 0.0002 |
# |      month, date, oppID     | 1.0000 | 1.0000 | 0.0001 |
# |      month, tmID, oppID     | 1.0000 | 1.0000 | 0.0002 |
# |    month, tmID, IDgoalie1   | 1.0000 | 1.0000 | 0.0002 |
# |    month, tmID, IDgoalie2   | 1.0000 | 1.0000 | 0.0002 |
# |   month, oppID, IDgoalie1   | 1.0000 | 1.0000 | 0.0002 |
# |    month, R/P, IDgoalie1    | 1.0000 | 1.0000 | 0.0002 |
# | month, IDgoalie1, IDgoalie2 | 1.0000 | 1.0000 | 0.0002 |
# |    month, R/P, IDgoalie2    | 0.9630 | 1.0000 | 0.0002 |
# |       tmID, oppID, R/P      | 0.9630 | 1.0000 | 0.0001 |
# |    tmID, oppID, IDgoalie1   | 0.9630 | 1.0000 | 0.0001 |
# |    oppID, R/P, IDgoalie1    | 0.9630 | 1.0000 | 0.0002 |
# |    year, tmID, IDgoalie2    | 0.9259 | 1.0000 | 0.0002 |
# |     year, R/P, IDgoalie2    | 0.9259 | 1.0000 | 0.0001 |
# |  year, IDgoalie1, IDgoalie2 | 0.9259 | 1.0000 | 0.0002 |
# |     tmID, R/P, IDgoalie2    | 0.9259 | 1.0000 | 0.0001 |
# |  tmID, IDgoalie1, IDgoalie2 | 0.9259 | 1.0000 | 0.0002 |
# |  R/P, IDgoalie1, IDgoalie2  | 0.9259 | 1.0000 | 0.0002 |
# |       year, month, R/P      | 0.8889 | 1.0000 | 0.0001 |
# |       year, tmID, R/P       | 0.8889 | 1.0000 | 0.0002 |
# |    year, tmID, IDgoalie1    | 0.8889 | 1.0000 | 0.0002 |
# |     year, R/P, IDgoalie1    | 0.8889 | 1.0000 | 0.0002 |
# |       month, date, R/P      | 0.8889 | 1.0000 | 0.0002 |
# |      month, oppID, R/P      | 0.8889 | 1.0000 | 0.0002 |
# |       date, oppID, R/P      | 0.8889 | 1.0000 | 0.0001 |
# |       month, tmID, R/P      | 0.7778 | 1.0000 | 0.0002 |
# +-----------------------------+--------+--------+--------+
#
# Column Count: 4
# +----------------------------------+--------+--------+--------+
# |            Top-5 Keys            |   UR   |   CR   |  Time  |
# +----------------------------------+--------+--------+--------+
# |   tmID, oppID, R/P, IDgoalie1    | 0.9630 | 1.0000 | 0.0001 |
# |    year, tmID, R/P, IDgoalie2    | 0.9259 | 1.0000 | 0.0001 |
# | year, tmID, IDgoalie1, IDgoalie2 | 0.9259 | 1.0000 | 0.0002 |
# | year, R/P, IDgoalie1, IDgoalie2  | 0.9259 | 1.0000 | 0.0001 |
# | tmID, R/P, IDgoalie1, IDgoalie2  | 0.9259 | 1.0000 | 0.0002 |
# |    year, tmID, R/P, IDgoalie1    | 0.8889 | 1.0000 | 0.0002 |
# +----------------------------------+--------+--------+--------+
#
# Column Count: 5
# +---------------------------------------+--------+--------+--------+
# |               Top-5 Keys              |   UR   |   CR   |  Time  |
# +---------------------------------------+--------+--------+--------+
# | year, tmID, R/P, IDgoalie1, IDgoalie2 | 0.9259 | 1.0000 | 0.0002 |
# +---------------------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +-----------------------------+--------+--------+
# |             Keys            |   UR   |   CR   |
# +-----------------------------+--------+--------+
# |          year, date         | 1.0000 | 1.0000 |
# |         year, oppID         | 1.0000 | 1.0000 |
# |          date, tmID         | 1.0000 | 1.0000 |
# |       date, IDgoalie1       | 1.0000 | 1.0000 |
# |       date, IDgoalie2       | 1.0000 | 1.0000 |
# |       oppID, IDgoalie2      | 1.0000 | 1.0000 |
# |       month, IDgoalie1      | 0.9630 | 1.0000 |
# |       month, IDgoalie2      | 0.9630 | 1.0000 |
# |         tmID, oppID         | 0.9630 | 1.0000 |
# |       oppID, IDgoalie1      | 0.9630 | 1.0000 |
# |      year, month, tmID      | 1.0000 | 1.0000 |
# |    year, month, IDgoalie1   | 1.0000 | 1.0000 |
# |    year, month, IDgoalie2   | 1.0000 | 1.0000 |
# |      month, date, oppID     | 1.0000 | 1.0000 |
# |      month, tmID, oppID     | 1.0000 | 1.0000 |
# |    month, tmID, IDgoalie1   | 1.0000 | 1.0000 |
# |    month, tmID, IDgoalie2   | 1.0000 | 1.0000 |
# |   month, oppID, IDgoalie1   | 1.0000 | 1.0000 |
# |    month, R/P, IDgoalie1    | 1.0000 | 1.0000 |
# | month, IDgoalie1, IDgoalie2 | 1.0000 | 1.0000 |
# |    month, R/P, IDgoalie2    | 0.9630 | 1.0000 |
# |       tmID, oppID, R/P      | 0.9630 | 1.0000 |
# |    tmID, oppID, IDgoalie1   | 0.9630 | 1.0000 |
# |    oppID, R/P, IDgoalie1    | 0.9630 | 1.0000 |
# | tmID, oppID, R/P, IDgoalie1 | 0.9630 | 1.0000 |
# +-----------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: goalies
# Columns: ['playerID', 'year', 'stint', 'tmID', 'lgID', 'GP']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 0.0535 | 1.0000 | 0.0012 |
# |     GP     | 0.0054 | 0.9951 | 0.0022 |
# |    tmID    | 0.0019 | 1.0000 | 0.0017 |
# |    year    | 0.0000 | 1.0000 | 0.0008 |
# |   stint    | 0.0000 | 1.0000 | 0.0013 |
# |    lgID    | 0.0000 | 1.0000 | 0.0023 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# | playerID, year | 0.8899 | 1.0000 | 0.0020 |
# |  playerID, GP  | 0.7910 | 0.9951 | 0.0035 |
# |    year, GP    | 0.3424 | 0.9951 | 0.0032 |
# |    tmID, GP    | 0.2637 | 0.9951 | 0.0032 |
# | playerID, tmID | 0.1982 | 1.0000 | 0.0025 |
# +----------------+--------+--------+--------+
#
# Column Count: 3
# +-----------------------+--------+--------+--------+
# |       Top-5 Keys      |   UR   |   CR   |  Time  |
# +-----------------------+--------+--------+--------+
# | playerID, year, stint | 1.0000 | 1.0000 | 0.0021 |
# |  playerID, year, tmID | 0.9995 | 1.0000 | 0.0034 |
# |   playerID, year, GP  | 0.9949 | 0.9951 | 0.0040 |
# |     year, tmID, GP    | 0.9565 | 0.9951 | 0.0039 |
# |  playerID, year, lgID | 0.8932 | 1.0000 | 0.0041 |
# +-----------------------+--------+--------+--------+
#
# Column Count: 4
# +----------------------------+--------+--------+--------+
# |         Top-5 Keys         |   UR   |   CR   |  Time  |
# +----------------------------+--------+--------+--------+
# |  playerID, year, tmID, GP  | 1.0000 | 0.9951 | 0.0050 |
# | playerID, year, tmID, lgID | 0.9995 | 1.0000 | 0.0051 |
# |  playerID, year, lgID, GP  | 0.9949 | 0.9951 | 0.0050 |
# |   year, stint, tmID, GP    | 0.9624 | 0.9951 | 0.0046 |
# |    year, tmID, lgID, GP    | 0.9565 | 0.9951 | 0.0052 |
# +----------------------------+--------+--------+--------+
#
# Column Count: 5
# +---------------------------------+--------+--------+--------+
# |            Top-5 Keys           |   UR   |   CR   |  Time  |
# +---------------------------------+--------+--------+--------+
# |   year, stint, tmID, lgID, GP   | 0.9624 | 0.9951 | 0.0054 |
# | playerID, stint, tmID, lgID, GP | 0.8901 | 0.9951 | 0.0052 |
# +---------------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +-----------------------------+--------+--------+
# |             Keys            |   UR   |   CR   |
# +-----------------------------+--------+--------+
# |    playerID, year, stint    | 1.0000 | 1.0000 |
# |     playerID, year, tmID    | 0.9995 | 1.0000 |
# |      playerID, year, GP     | 0.9949 | 0.9951 |
# |        year, tmID, GP       | 0.9565 | 0.9951 |
# |   playerID, year, tmID, GP  | 1.0000 | 0.9951 |
# |  playerID, year, tmID, lgID | 0.9995 | 1.0000 |
# |   playerID, year, lgID, GP  | 0.9949 | 0.9951 |
# |    year, stint, tmID, GP    | 0.9624 | 0.9951 |
# |     year, tmID, lgID, GP    | 0.9565 | 0.9951 |
# | year, stint, tmID, lgID, GP | 0.9624 | 0.9951 |
# +-----------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: goaliessc
# Columns: ['playerID', 'year', 'tmID', 'lgID', 'GP']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    tmID    | 0.2903 | 1.0000 | 0.0002 |
# |  playerID  | 0.1935 | 1.0000 | 0.0003 |
# |     GP     | 0.0645 | 1.0000 | 0.0002 |
# |    year    | 0.0000 | 1.0000 | 0.0002 |
# |    lgID    | 0.0000 | 1.0000 | 0.0001 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# | playerID, year | 1.0000 | 1.0000 | 0.0002 |
# |   year, tmID   | 0.9355 | 1.0000 | 0.0002 |
# |   year, lgID   | 0.9355 | 1.0000 | 0.0002 |
# |    tmID, GP    | 0.5806 | 1.0000 | 0.0001 |
# |  playerID, GP  | 0.4194 | 1.0000 | 0.0002 |
# | playerID, tmID | 0.3226 | 1.0000 | 0.0002 |
# +----------------+--------+--------+--------+
#
# Column Count: 3
# +----------------------+--------+--------+--------+
# |      Top-5 Keys      |   UR   |   CR   |  Time  |
# +----------------------+--------+--------+--------+
# |    year, tmID, GP    | 1.0000 | 1.0000 | 0.0002 |
# |    year, lgID, GP    | 1.0000 | 1.0000 | 0.0002 |
# |   year, tmID, lgID   | 0.9355 | 1.0000 | 0.0001 |
# |  playerID, tmID, GP  | 0.5806 | 1.0000 | 0.0002 |
# |  playerID, lgID, GP  | 0.5806 | 1.0000 | 0.0002 |
# |    tmID, lgID, GP    | 0.5806 | 1.0000 | 0.0002 |
# | playerID, tmID, lgID | 0.3226 | 1.0000 | 0.0002 |
# +----------------------+--------+--------+--------+
#
# Column Count: 4
# +--------------------------+--------+--------+--------+
# |        Top-5 Keys        |   UR   |   CR   |  Time  |
# +--------------------------+--------+--------+--------+
# | playerID, tmID, lgID, GP | 0.5806 | 1.0000 | 0.0002 |
# +--------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +----------------+--------+--------+
# |      Keys      |   UR   |   CR   |
# +----------------+--------+--------+
# | playerID, year | 1.0000 | 1.0000 |
# | year, tmID, GP | 1.0000 | 1.0000 |
# | year, lgID, GP | 1.0000 | 1.0000 |
# +----------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: goaliesshootout
# Columns: ['playerID', 'year', 'stint', 'tmID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 0.0563 | 1.0000 | 0.0004 |
# |    tmID    | 0.0021 | 1.0000 | 0.0003 |
# |    year    | 0.0000 | 1.0000 | 0.0002 |
# |   stint    | 0.0000 | 1.0000 | 0.0003 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-----------------+--------+--------+--------+
# |    Top-5 Keys   |   UR   |   CR   |  Time  |
# +-----------------+--------+--------+--------+
# |  playerID, year | 0.9542 | 1.0000 | 0.0004 |
# |  playerID, tmID | 0.2375 | 1.0000 | 0.0005 |
# | playerID, stint | 0.0833 | 1.0000 | 0.0004 |
# |    year, tmID   | 0.0229 | 1.0000 | 0.0003 |
# |   stint, tmID   | 0.0188 | 1.0000 | 0.0004 |
# +-----------------+--------+--------+--------+
#
# Column Count: 3
# +-----------------------+--------+--------+--------+
# |       Top-5 Keys      |   UR   |   CR   |  Time  |
# +-----------------------+--------+--------+--------+
# | playerID, year, stint | 1.0000 | 1.0000 | 0.0005 |
# |  playerID, year, tmID | 1.0000 | 1.0000 | 0.0006 |
# | playerID, stint, tmID | 0.2583 | 1.0000 | 0.0005 |
# |   year, stint, tmID   | 0.0604 | 1.0000 | 0.0005 |
# +-----------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +-----------------------+--------+--------+
# |          Keys         |   UR   |   CR   |
# +-----------------------+--------+--------+
# |     playerID, year    | 0.9542 | 1.0000 |
# | playerID, year, stint | 1.0000 | 1.0000 |
# |  playerID, year, tmID | 1.0000 | 1.0000 |
# +-----------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: hof
# Columns: ['year', 'hofID', 'name', 'category']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |   hofID    | 1.0000 | 1.0000 | 0.0003 |
# |    name    | 0.9945 | 1.0000 | 0.0004 |
# |    year    | 0.0000 | 1.0000 | 0.0004 |
# |  category  | 0.0000 | 1.0000 | 0.0004 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# |   year, name   | 1.0000 | 1.0000 | 0.0005 |
# | name, category | 0.9945 | 1.0000 | 0.0005 |
# | year, category | 0.1205 | 1.0000 | 0.0004 |
# +----------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +----------------+--------+--------+
# |      Keys      |   UR   |   CR   |
# +----------------+--------+--------+
# |     hofID      | 1.0000 | 1.0000 |
# |      name      | 0.9945 | 1.0000 |
# |   year, name   | 1.0000 | 1.0000 |
# | name, category | 0.9945 | 1.0000 |
# +----------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: master
# Columns: ['playerID', 'coachID', 'hofID', 'legendsID', 'ihdbID', 'hrefID', 'lastName', 'nameGiven', 'birthYear', 'pos']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 1.0000 | 0.9689 | 0.0031 |
# |  coachID   | 1.0000 | 0.0509 | 0.0019 |
# |   hofID    | 1.0000 | 0.0472 | 0.0019 |
# | legendsID  | 1.0000 | 0.8474 | 0.0063 |
# |   ihdbID   | 1.0000 | 0.9181 | 0.0063 |
# |   hrefID   | 1.0000 | 0.9608 | 0.0080 |
# | nameGiven  | 0.6329 | 0.7712 | 0.0057 |
# |  lastName  | 0.5055 | 1.0000 | 0.0048 |
# |    pos     | 0.0412 | 0.9595 | 0.0046 |
# | birthYear  | 0.0289 | 0.9719 | 0.0049 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------------+--------+--------+--------+
# |      Top-5 Keys      |   UR   |   CR   |  Time  |
# +----------------------+--------+--------+--------+
# | lastName, nameGiven  | 0.9985 | 0.7712 | 0.0081 |
# | lastName, birthYear  | 0.9693 | 0.9719 | 0.0082 |
# | nameGiven, birthYear | 0.9340 | 0.7572 | 0.0076 |
# |    nameGiven, pos    | 0.7878 | 0.7451 | 0.0072 |
# +----------------------+--------+--------+--------+
#
# Column Count: 3
# +--------------------------------+--------+--------+--------+
# |           Top-5 Keys           |   UR   |   CR   |  Time  |
# +--------------------------------+--------+--------+--------+
# | lastName, nameGiven, birthYear | 1.0000 | 0.7572 | 0.0093 |
# |    lastName, nameGiven, pos    | 0.9997 | 0.7451 | 0.0091 |
# |    lastName, birthYear, pos    | 0.9941 | 0.9476 | 0.0093 |
# |   nameGiven, birthYear, pos    | 0.9822 | 0.7388 | 0.0085 |
# +--------------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +--------------------------------+--------+--------+
# |              Keys              |   UR   |   CR   |
# +--------------------------------+--------+--------+
# |            playerID            | 1.0000 | 0.9689 |
# |            coachID             | 1.0000 | 0.0509 |
# |             hofID              | 1.0000 | 0.0472 |
# |           legendsID            | 1.0000 | 0.8474 |
# |             ihdbID             | 1.0000 | 0.9181 |
# |             hrefID             | 1.0000 | 0.9608 |
# |      lastName, nameGiven       | 0.9985 | 0.7712 |
# |      lastName, birthYear       | 0.9693 | 0.9719 |
# | lastName, nameGiven, birthYear | 1.0000 | 0.7572 |
# |    lastName, nameGiven, pos    | 0.9997 | 0.7451 |
# |    lastName, birthYear, pos    | 0.9941 | 0.9476 |
# |   nameGiven, birthYear, pos    | 0.9822 | 0.7388 |
# +--------------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: scoring
# Columns: ['playerID', 'year', 'stint', 'tmID', 'lgID', 'pos']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 0.0370 | 1.0000 | 0.0125 |
# |    pos     | 0.0127 | 0.9873 | 0.0275 |
# |    year    | 0.0000 | 1.0000 | 0.0110 |
# |   stint    | 0.0000 | 1.0000 | 0.0247 |
# |    tmID    | 0.0000 | 1.0000 | 0.0175 |
# |    lgID    | 0.0000 | 1.0000 | 0.0282 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-----------------+--------+--------+--------+
# |    Top-5 Keys   |   UR   |   CR   |  Time  |
# +-----------------+--------+--------+--------+
# |  playerID, year | 0.8396 | 1.0000 | 0.0349 |
# |  playerID, tmID | 0.1789 | 1.0000 | 0.0408 |
# | playerID, stint | 0.0732 | 1.0000 | 0.0372 |
# |  playerID, pos  | 0.0656 | 0.9873 | 0.0370 |
# |  playerID, lgID | 0.0439 | 1.0000 | 0.0379 |
# +-----------------+--------+--------+--------+
#
# Column Count: 3
# +-----------------------+--------+--------+--------+
# |       Top-5 Keys      |   UR   |   CR   |  Time  |
# +-----------------------+--------+--------+--------+
# | playerID, year, stint | 0.9999 | 1.0000 | 0.0475 |
# |  playerID, year, tmID | 0.9996 | 1.0000 | 0.0515 |
# |  playerID, year, pos  | 0.8436 | 0.9873 | 0.0495 |
# |  playerID, year, lgID | 0.8419 | 1.0000 | 0.0525 |
# | playerID, stint, tmID | 0.2487 | 1.0000 | 0.0454 |
# +-----------------------+--------+--------+--------+
#
# Column Count: 4
# +-----------------------------+--------+--------+--------+
# |          Top-5 Keys         |   UR   |   CR   |  Time  |
# +-----------------------------+--------+--------+--------+
# | playerID, year, stint, tmID | 1.0000 | 1.0000 | 0.0558 |
# |  playerID, year, stint, pos | 1.0000 | 0.9873 | 0.0543 |
# | playerID, year, stint, lgID | 0.9999 | 1.0000 | 0.0554 |
# |  playerID, year, tmID, lgID | 0.9996 | 1.0000 | 0.0592 |
# |  playerID, year, tmID, pos  | 0.9996 | 0.9873 | 0.0571 |
# |  playerID, year, lgID, pos  | 0.8456 | 0.9873 | 0.0560 |
# |  playerID, stint, tmID, pos | 0.2859 | 0.9873 | 0.0497 |
# +-----------------------------+--------+--------+--------+
#
# Column Count: 5
# +----------------------------------+--------+--------+--------+
# |            Top-5 Keys            |   UR   |   CR   |  Time  |
# +----------------------------------+--------+--------+--------+
# | playerID, year, tmID, lgID, pos  | 0.9996 | 0.9873 | 0.0603 |
# | playerID, stint, tmID, lgID, pos | 0.2859 | 0.9873 | 0.0555 |
# |   year, stint, tmID, lgID, pos   | 0.0707 | 0.9873 | 0.0508 |
# +----------------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +---------------------------------+--------+--------+
# |               Keys              |   UR   |   CR   |
# +---------------------------------+--------+--------+
# |      playerID, year, stint      | 0.9999 | 1.0000 |
# |       playerID, year, tmID      | 0.9996 | 1.0000 |
# |   playerID, year, stint, tmID   | 1.0000 | 1.0000 |
# |    playerID, year, stint, pos   | 1.0000 | 0.9873 |
# |   playerID, year, stint, lgID   | 0.9999 | 1.0000 |
# |    playerID, year, tmID, lgID   | 0.9996 | 1.0000 |
# |    playerID, year, tmID, pos    | 0.9996 | 0.9873 |
# | playerID, year, tmID, lgID, pos | 0.9996 | 0.9873 |
# +---------------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: scoringsc
# Columns: ['playerID', 'year', 'tmID', 'lgID', 'pos']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 0.2570 | 1.0000 | 0.0003 |
# |    pos     | 0.0070 | 1.0000 | 0.0002 |
# |    year    | 0.0000 | 1.0000 | 0.0002 |
# |    tmID    | 0.0000 | 1.0000 | 0.0003 |
# |    lgID    | 0.0000 | 1.0000 | 0.0003 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# | playerID, year | 1.0000 | 1.0000 | 0.0003 |
# | playerID, tmID | 0.4683 | 1.0000 | 0.0003 |
# | playerID, lgID | 0.3697 | 1.0000 | 0.0003 |
# | playerID, pos  | 0.3275 | 1.0000 | 0.0003 |
# |   tmID, pos    | 0.0915 | 1.0000 | 0.0003 |
# +----------------+--------+--------+--------+
#
# Column Count: 3
# +----------------------+--------+--------+--------+
# |      Top-5 Keys      |   UR   |   CR   |  Time  |
# +----------------------+--------+--------+--------+
# | playerID, tmID, pos  | 0.5070 | 1.0000 | 0.0004 |
# | playerID, tmID, lgID | 0.4683 | 1.0000 | 0.0004 |
# | playerID, lgID, pos  | 0.4331 | 1.0000 | 0.0004 |
# |   year, tmID, pos    | 0.2817 | 1.0000 | 0.0003 |
# |   year, lgID, pos    | 0.2817 | 1.0000 | 0.0004 |
# +----------------------+--------+--------+--------+
#
# Column Count: 4
# +---------------------------+--------+--------+--------+
# |         Top-5 Keys        |   UR   |   CR   |  Time  |
# +---------------------------+--------+--------+--------+
# | playerID, tmID, lgID, pos | 0.5070 | 1.0000 | 0.0004 |
# |   year, tmID, lgID, pos   | 0.2817 | 1.0000 | 0.0004 |
# +---------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +----------------+--------+--------+
# |      Keys      |   UR   |   CR   |
# +----------------+--------+--------+
# | playerID, year | 1.0000 | 1.0000 |
# +----------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: scoringshootout
# Columns: ['playerID', 'year', 'stint', 'tmID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 0.1100 | 1.0000 | 0.0008 |
# |    year    | 0.0000 | 1.0000 | 0.0006 |
# |   stint    | 0.0000 | 1.0000 | 0.0010 |
# |    tmID    | 0.0000 | 1.0000 | 0.0009 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-----------------+--------+--------+--------+
# |    Top-5 Keys   |   UR   |   CR   |  Time  |
# +-----------------+--------+--------+--------+
# |  playerID, year | 0.9257 | 1.0000 | 0.0015 |
# |  playerID, tmID | 0.2823 | 1.0000 | 0.0018 |
# | playerID, stint | 0.1506 | 1.0000 | 0.0015 |
# |   stint, tmID   | 0.0043 | 1.0000 | 0.0014 |
# |   year, stint   | 0.0014 | 1.0000 | 0.0013 |
# +-----------------+--------+--------+--------+
#
# Column Count: 3
# +-----------------------+--------+--------+--------+
# |       Top-5 Keys      |   UR   |   CR   |  Time  |
# +-----------------------+--------+--------+--------+
# | playerID, year, stint | 1.0000 | 1.0000 | 0.0020 |
# |  playerID, year, tmID | 1.0000 | 1.0000 | 0.0022 |
# | playerID, stint, tmID | 0.3152 | 1.0000 | 0.0020 |
# |   year, stint, tmID   | 0.0299 | 1.0000 | 0.0016 |
# +-----------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +-----------------------+--------+--------+
# |          Keys         |   UR   |   CR   |
# +-----------------------+--------+--------+
# | playerID, year, stint | 1.0000 | 1.0000 |
# |  playerID, year, tmID | 1.0000 | 1.0000 |
# +-----------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: scoringsup
# Columns: ['playerID', 'year']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |  playerID  | 0.7445 | 1.0000 | 0.0003 |
# |    year    | 0.0000 | 1.0000 | 0.0002 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +----------------+--------+--------+--------+
# |   Top-5 Keys   |   UR   |   CR   |  Time  |
# +----------------+--------+--------+--------+
# | playerID, year | 1.0000 | 1.0000 | 0.0002 |
# +----------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +----------------+--------+--------+
# |      Keys      |   UR   |   CR   |
# +----------------+--------+--------+
# | playerID, year | 1.0000 | 1.0000 |
# +----------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: seriespost
# Columns: ['year', 'round', 'series', 'tmIDWinner', 'lgIDWinner', 'tmIDLoser', 'lgIDLoser']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |   series   | 0.1118 | 0.8882 | 0.0005 |
# | tmIDLoser  | 0.0240 | 1.0000 | 0.0005 |
# | tmIDWinner | 0.0132 | 1.0000 | 0.0005 |
# |    year    | 0.0024 | 1.0000 | 0.0004 |
# |   round    | 0.0012 | 1.0000 | 0.0006 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-----------------------+--------+--------+--------+
# |       Top-5 Keys      |   UR   |   CR   |  Time  |
# +-----------------------+--------+--------+--------+
# |      year, series     | 1.0000 | 0.8882 | 0.0007 |
# |    year, tmIDLoser    | 0.9928 | 1.0000 | 0.0006 |
# | tmIDWinner, tmIDLoser | 0.2921 | 1.0000 | 0.0007 |
# |    year, tmIDWinner   | 0.2800 | 1.0000 | 0.0005 |
# |   series, tmIDLoser   | 0.2464 | 0.8882 | 0.0007 |
# +-----------------------+--------+--------+--------+
#
# Column Count: 3
# +-------------------------------+--------+--------+--------+
# |           Top-5 Keys          |   UR   |   CR   |  Time  |
# +-------------------------------+--------+--------+--------+
# |    year, round, tmIDWinner    | 1.0000 | 1.0000 | 0.0009 |
# |     year, round, tmIDLoser    | 1.0000 | 1.0000 | 0.0009 |
# |  year, tmIDWinner, tmIDLoser  | 1.0000 | 1.0000 | 0.0009 |
# |  year, lgIDWinner, tmIDLoser  | 0.9952 | 1.0000 | 0.0009 |
# |   year, tmIDLoser, lgIDLoser  | 0.9928 | 1.0000 | 0.0009 |
# | series, tmIDWinner, tmIDLoser | 0.6587 | 0.8882 | 0.0008 |
# |  round, tmIDWinner, tmIDLoser | 0.5601 | 1.0000 | 0.0010 |
# +-------------------------------+--------+--------+--------+
#
# Column Count: 4
# +-------------------------------------------+--------+--------+--------+
# |                 Top-5 Keys                |   UR   |   CR   |  Time  |
# +-------------------------------------------+--------+--------+--------+
# |   year, lgIDWinner, tmIDLoser, lgIDLoser  | 0.9952 | 1.0000 | 0.0011 |
# |    round, series, tmIDWinner, tmIDLoser   | 0.7115 | 0.8882 | 0.0010 |
# | series, tmIDWinner, lgIDWinner, tmIDLoser | 0.6587 | 0.8882 | 0.0011 |
# |  series, tmIDWinner, tmIDLoser, lgIDLoser | 0.6587 | 0.8882 | 0.0010 |
# |  round, tmIDWinner, lgIDWinner, tmIDLoser | 0.5601 | 1.0000 | 0.0011 |
# |  round, tmIDWinner, tmIDLoser, lgIDLoser  | 0.5601 | 1.0000 | 0.0010 |
# +-------------------------------------------+--------+--------+--------+
#
# Column Count: 5
# +------------------------------------------------------+--------+--------+--------+
# |                      Top-5 Keys                      |   UR   |   CR   |  Time  |
# +------------------------------------------------------+--------+--------+--------+
# |   round, series, tmIDWinner, lgIDWinner, tmIDLoser   | 0.7115 | 0.8882 | 0.0011 |
# |   round, series, tmIDWinner, tmIDLoser, lgIDLoser    | 0.7115 | 0.8882 | 0.0011 |
# | series, tmIDWinner, lgIDWinner, tmIDLoser, lgIDLoser | 0.6587 | 0.8882 | 0.0010 |
# | round, tmIDWinner, lgIDWinner, tmIDLoser, lgIDLoser  | 0.5601 | 1.0000 | 0.0011 |
# |   round, series, lgIDWinner, tmIDLoser, lgIDLoser    | 0.3450 | 0.8882 | 0.0010 |
# +------------------------------------------------------+--------+--------+--------+
#
# Column Count: 6
# +-------------------------------------------------------------+--------+--------+--------+
# |                          Top-5 Keys                         |   UR   |   CR   |  Time  |
# +-------------------------------------------------------------+--------+--------+--------+
# | round, series, tmIDWinner, lgIDWinner, tmIDLoser, lgIDLoser | 0.7115 | 0.8882 | 0.0011 |
# +-------------------------------------------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +----------------------------------------+--------+--------+
# |                  Keys                  |   UR   |   CR   |
# +----------------------------------------+--------+--------+
# |              year, series              | 1.0000 | 0.8882 |
# |            year, tmIDLoser             | 0.9928 | 1.0000 |
# |        year, round, tmIDWinner         | 1.0000 | 1.0000 |
# |         year, round, tmIDLoser         | 1.0000 | 1.0000 |
# |      year, tmIDWinner, tmIDLoser       | 1.0000 | 1.0000 |
# |      year, lgIDWinner, tmIDLoser       | 0.9952 | 1.0000 |
# |       year, tmIDLoser, lgIDLoser       | 0.9928 | 1.0000 |
# | year, lgIDWinner, tmIDLoser, lgIDLoser | 0.9952 | 1.0000 |
# +----------------------------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: teams
# Columns: ['year', 'lgID', 'tmID', 'franchID', 'confID', 'divID', 'rank', 'name']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |   confID   | 0.4062 | 0.5938 | 0.0007 |
# |   divID    | 0.2291 | 0.7709 | 0.0008 |
# |    tmID    | 0.0158 | 1.0000 | 0.0004 |
# |    name    | 0.0138 | 1.0000 | 0.0011 |
# |  franchID  | 0.0026 | 1.0000 | 0.0008 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +------------------+--------+--------+--------+
# |    Top-5 Keys    |   UR   |   CR   |  Time  |
# +------------------+--------+--------+--------+
# |    year, tmID    | 1.0000 | 1.0000 | 0.0006 |
# |  year, franchID  | 1.0000 | 1.0000 | 0.0012 |
# |    year, name    | 1.0000 | 1.0000 | 0.0015 |
# |   tmID, confID   | 0.4082 | 0.5938 | 0.0009 |
# |   confID, name   | 0.4082 | 0.5938 | 0.0011 |
# | franchID, confID | 0.4075 | 0.5938 | 0.0010 |
# |   year, confID   | 0.4062 | 0.5938 | 0.0009 |
# |   lgID, confID   | 0.4062 | 0.5938 | 0.0009 |
# |  confID, divID   | 0.4062 | 0.5938 | 0.0009 |
# |   confID, rank   | 0.4062 | 0.5938 | 0.0009 |
# |   tmID, divID    | 0.2449 | 0.7709 | 0.0009 |
# |   divID, name    | 0.2449 | 0.7709 | 0.0012 |
# +------------------+--------+--------+--------+
#
# Column Count: 3
# +------------------------+--------+--------+--------+
# |       Top-5 Keys       |   UR   |   CR   |  Time  |
# +------------------------+--------+--------+--------+
# |   year, divID, rank    | 1.0000 | 0.7709 | 0.0011 |
# |   confID, rank, name   | 0.4602 | 0.5938 | 0.0012 |
# |   tmID, confID, rank   | 0.4589 | 0.5938 | 0.0010 |
# | franchID, confID, rank | 0.4549 | 0.5938 | 0.0011 |
# |   year, confID, rank   | 0.4266 | 0.5938 | 0.0010 |
# +------------------------+--------+--------+--------+
#
# Column Count: 4
# +-------------------------------+--------+--------+--------+
# |           Top-5 Keys          |   UR   |   CR   |  Time  |
# +-------------------------------+--------+--------+--------+
# |   confID, divID, rank, name   | 0.4779 | 0.5938 | 0.0013 |
# |   tmID, confID, divID, rank   | 0.4760 | 0.5938 | 0.0012 |
# | franchID, confID, divID, rank | 0.4720 | 0.5938 | 0.0013 |
# |    lgID, confID, rank, name   | 0.4602 | 0.5938 | 0.0016 |
# |    tmID, confID, rank, name   | 0.4602 | 0.5938 | 0.0013 |
# |  franchID, confID, rank, name | 0.4602 | 0.5938 | 0.0014 |
# +-------------------------------+--------+--------+--------+
#
# Column Count: 5
# +-------------------------------------+--------+--------+--------+
# |              Top-5 Keys             |   UR   |   CR   |  Time  |
# +-------------------------------------+--------+--------+--------+
# |   lgID, confID, divID, rank, name   | 0.4779 | 0.5938 | 0.0015 |
# |   tmID, confID, divID, rank, name   | 0.4779 | 0.5938 | 0.0015 |
# | franchID, confID, divID, rank, name | 0.4779 | 0.5938 | 0.0015 |
# |   lgID, tmID, confID, divID, rank   | 0.4760 | 0.5938 | 0.0013 |
# | tmID, franchID, confID, divID, rank | 0.4760 | 0.5938 | 0.0013 |
# | lgID, franchID, confID, divID, rank | 0.4720 | 0.5938 | 0.0014 |
# |    lgID, tmID, confID, rank, name   | 0.4602 | 0.5938 | 0.0016 |
# |  lgID, franchID, confID, rank, name | 0.4602 | 0.5938 | 0.0015 |
# |  tmID, franchID, confID, rank, name | 0.4602 | 0.5938 | 0.0014 |
# +-------------------------------------+--------+--------+--------+
#
# Column Count: 6
# +-------------------------------------------+--------+--------+--------+
# |                 Top-5 Keys                |   UR   |   CR   |  Time  |
# +-------------------------------------------+--------+--------+--------+
# |   lgID, tmID, confID, divID, rank, name   | 0.4779 | 0.5938 | 0.0015 |
# | lgID, franchID, confID, divID, rank, name | 0.4779 | 0.5938 | 0.0016 |
# | tmID, franchID, confID, divID, rank, name | 0.4779 | 0.5938 | 0.0016 |
# | lgID, tmID, franchID, confID, divID, rank | 0.4760 | 0.5938 | 0.0014 |
# |  lgID, tmID, franchID, confID, rank, name | 0.4602 | 0.5938 | 0.0016 |
# | lgID, tmID, franchID, confID, divID, name | 0.4101 | 0.5938 | 0.0016 |
# +-------------------------------------------+--------+--------+--------+
#
# Column Count: 7
# +-------------------------------------------------+--------+--------+--------+
# |                    Top-5 Keys                   |   UR   |   CR   |  Time  |
# +-------------------------------------------------+--------+--------+--------+
# | lgID, tmID, franchID, confID, divID, rank, name | 0.4779 | 0.5938 | 0.0018 |
# +-------------------------------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +-------------------+--------+--------+
# |        Keys       |   UR   |   CR   |
# +-------------------+--------+--------+
# |     year, tmID    | 1.0000 | 1.0000 |
# |   year, franchID  | 1.0000 | 1.0000 |
# |     year, name    | 1.0000 | 1.0000 |
# | year, divID, rank | 1.0000 | 0.7709 |
# +-------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: teamshalf
# Columns: ['year', 'lgID', 'tmID', 'half', 'rank']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    tmID    | 0.0244 | 1.0000 | 0.0001 |
# |    year    | 0.0000 | 1.0000 | 0.0002 |
# |    lgID    | 0.0000 | 1.0000 | 0.0002 |
# |    half    | 0.0000 | 1.0000 | 0.0001 |
# |    rank    | 0.0000 | 1.0000 | 0.0001 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# | tmID, half | 0.4146 | 1.0000 | 0.0002 |
# | tmID, rank | 0.4146 | 1.0000 | 0.0001 |
# | half, rank | 0.0976 | 1.0000 | 0.0002 |
# | year, tmID | 0.0244 | 1.0000 | 0.0002 |
# | year, rank | 0.0244 | 1.0000 | 0.0002 |
# | lgID, tmID | 0.0244 | 1.0000 | 0.0002 |
# | year, lgID | 0.0000 | 1.0000 | 0.0002 |
# | year, half | 0.0000 | 1.0000 | 0.0002 |
# | lgID, half | 0.0000 | 1.0000 | 0.0001 |
# | lgID, rank | 0.0000 | 1.0000 | 0.0002 |
# +------------+--------+--------+--------+
#
# Column Count: 3
# +------------------+--------+--------+--------+
# |    Top-5 Keys    |   UR   |   CR   |  Time  |
# +------------------+--------+--------+--------+
# | year, tmID, half | 1.0000 | 1.0000 | 0.0002 |
# | year, half, rank | 1.0000 | 1.0000 | 0.0002 |
# | year, tmID, rank | 0.8049 | 1.0000 | 0.0002 |
# | tmID, half, rank | 0.7561 | 1.0000 | 0.0002 |
# | lgID, tmID, half | 0.4146 | 1.0000 | 0.0002 |
# | lgID, tmID, rank | 0.4146 | 1.0000 | 0.0002 |
# | lgID, half, rank | 0.2927 | 1.0000 | 0.0002 |
# +------------------+--------+--------+--------+
#
# Column Count: 4
# +------------------------+--------+--------+--------+
# |       Top-5 Keys       |   UR   |   CR   |  Time  |
# +------------------------+--------+--------+--------+
# | year, lgID, tmID, rank | 0.8049 | 1.0000 | 0.0002 |
# | lgID, tmID, half, rank | 0.7561 | 1.0000 | 0.0001 |
# +------------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +------------------+--------+--------+
# |       Keys       |   UR   |   CR   |
# +------------------+--------+--------+
# | year, tmID, half | 1.0000 | 1.0000 |
# | year, half, rank | 1.0000 | 1.0000 |
# +------------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: teamsplits
# Columns: ['year', 'lgID', 'tmID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    tmID    | 0.0158 | 1.0000 | 0.0005 |
# |    year    | 0.0000 | 1.0000 | 0.0004 |
# |    lgID    | 0.0000 | 1.0000 | 0.0009 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# | year, tmID | 1.0000 | 1.0000 | 0.0007 |
# | lgID, tmID | 0.0158 | 1.0000 | 0.0011 |
# | year, lgID | 0.0000 | 1.0000 | 0.0010 |
# +------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +------------+--------+--------+
# |    Keys    |   UR   |   CR   |
# +------------+--------+--------+
# | year, tmID | 1.0000 | 1.0000 |
# +------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: teamspost
# Columns: ['year', 'lgID', 'tmID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    tmID    | 0.0162 | 1.0000 | 0.0003 |
# |    year    | 0.0000 | 1.0000 | 0.0003 |
# |    lgID    | 0.0000 | 1.0000 | 0.0005 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# | year, tmID | 1.0000 | 1.0000 | 0.0004 |
# | lgID, tmID | 0.0162 | 1.0000 | 0.0006 |
# | year, lgID | 0.0000 | 1.0000 | 0.0006 |
# +------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +------------+--------+--------+
# |    Keys    |   UR   |   CR   |
# +------------+--------+--------+
# | year, tmID | 1.0000 | 1.0000 |
# +------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: teamssc
# Columns: ['year', 'lgID', 'tmID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    tmID    | 0.3000 | 1.0000 | 0.0001 |
# |    year    | 0.0000 | 1.0000 | 0.0002 |
# |    lgID    | 0.0000 | 1.0000 | 0.0002 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# | year, lgID | 1.0000 | 1.0000 | 0.0002 |
# | year, tmID | 1.0000 | 1.0000 | 0.0002 |
# | lgID, tmID | 0.3000 | 1.0000 | 0.0002 |
# +------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +------------+--------+--------+
# |    Keys    |   UR   |   CR   |
# +------------+--------+--------+
# | year, lgID | 1.0000 | 1.0000 |
# | year, tmID | 1.0000 | 1.0000 |
# +------------+--------+--------+
# ---------------------------------------------------------------------------------------------------------
#
# Table: teamvsteam
# Columns: ['year', 'lgID', 'tmID', 'oppID']
#
# Column Count: 1
# +------------+--------+--------+--------+
# | Top-5 Keys |   UR   |   CR   |  Time  |
# +------------+--------+--------+--------+
# |    year    | 0.0000 | 1.0000 | 0.0044 |
# |    lgID    | 0.0000 | 1.0000 | 0.0113 |
# |    tmID    | 0.0000 | 1.0000 | 0.0079 |
# |   oppID    | 0.0000 | 1.0000 | 0.0045 |
# +------------+--------+--------+--------+
#
# Column Count: 2
# +-------------+--------+--------+--------+
# |  Top-5 Keys |   UR   |   CR   |  Time  |
# +-------------+--------+--------+--------+
# | tmID, oppID | 0.0178 | 1.0000 | 0.0111 |
# |  year, lgID | 0.0000 | 1.0000 | 0.0135 |
# |  year, tmID | 0.0000 | 1.0000 | 0.0055 |
# | year, oppID | 0.0000 | 1.0000 | 0.0094 |
# |  lgID, tmID | 0.0000 | 1.0000 | 0.0145 |
# | lgID, oppID | 0.0000 | 1.0000 | 0.0144 |
# +-------------+--------+--------+--------+
#
# Column Count: 3
# +-------------------+--------+--------+--------+
# |     Top-5 Keys    |   UR   |   CR   |  Time  |
# +-------------------+--------+--------+--------+
# | year, tmID, oppID | 1.0000 | 1.0000 | 0.0107 |
# | lgID, tmID, oppID | 0.0178 | 1.0000 | 0.0199 |
# |  year, lgID, tmID | 0.0000 | 1.0000 | 0.0165 |
# | year, lgID, oppID | 0.0000 | 1.0000 | 0.0164 |
# +-------------------+--------+--------+--------+
#
# Near-Keys (UR >= 95%):
# +-------------------+--------+--------+
# |        Keys       |   UR   |   CR   |
# +-------------------+--------+--------+
# | year, tmID, oppID | 1.0000 | 1.0000 |
# +-------------------+--------+--------+

# %% [markdown]
# # Degree of violation distribution

# %%
import numpy as np


def degree_of_violation(cursor, table_name, columns):
    if not columns:
        return 0, 0
    query = f"""
        SELECT {', '.join([f"`{col}`" for col in columns])}, COUNT(*) AS group_count 
        FROM `{table_name}` 
        WHERE {' AND '.join([f"`{col}` IS NOT NULL" for col in columns])}
        GROUP BY {', '.join([f"`{col}`" for col in columns])}
        HAVING COUNT(*) > 1;
    """
    query2 = f"""
        SELECT ss.*, group_count
        FROM (
            SELECT {', '.join([f"`{col}`" for col in columns])}, COUNT(*) AS group_count
            FROM {table_name}
            GROUP BY {', '.join([f"`{col}`" for col in columns])}
            HAVING COUNT(*) > 1
        ) dup
        JOIN `{table_name}` ss ON {' AND '.join([f"ss.`{col}` IS NOT NULL" for col in columns])} AND {' AND '.join([f"dup.`{col}` IS NOT NULL" for col in columns])} AND {' AND '.join([f"ss.`{col}` = dup.`{col}`" for col in columns])};
    """
    cursor.execute(query2)
    group_table = cursor.fetchall()
    # print(query2)
    
    # print(group_table)
    return group_table



def main_degree(database, table_name, columns):
    try:
        connection = mysql.connector.connect(user = "root", password = "yzh_20010315", database = database)

        if connection.is_connected():
            cursor = connection.cursor()
            group_table = degree_of_violation(cursor, table_name, columns)
            # print(group_table)
            duplicate_dic = {}
            for item in group_table:
                key = item[-1]
                value = item[:-1]
                if key in duplicate_dic:
                    duplicate_dic[key].append(list(value))
                else:
                    duplicate_dic[key] = [list(value)]
            # print("group_table: ", group_table)
            
            x = list(duplicate_dic.keys())
            y = [int(len(value) / key) for key, value in duplicate_dic.items()]
            # print(x, "\n", y)
            
            if len(x) != 1:
                # Ensure x and y are sorted by x
                sorted_data = sorted(zip(x, y))
                x, y = zip(*sorted_data)
                
                # Create the bar chart
                colors = plt.cm.Paired.colors[:len(x)]
                plt.figure(figsize=(10, 5))
                plt.bar(x, y, color=colors, alpha=0.7)
                
                # Use logarithmic scale for y-axis
                plt.yscale('log')
                
                # Set custom tick positions for better readability
                y_ticks = np.logspace(0, np.ceil(np.log10(max(y))), num=10, base=10.0)
                plt.yticks(y_ticks, [f"{int(tick)}" for tick in y_ticks])
                
                # Display values on top of each bar
                for i in range(len(x)):
                    plt.text(x[i], y[i], f'{y[i]}', fontsize=16, ha='center', va='bottom')
                
                # Set labels and title
                plt.xlabel('Degree of Violation')
                plt.ylabel('Number')
                # plt.title(f"Duplicate Distribution for Near-Key {columns}")
                
                # Show the chart
                plt.show()
                
            else:
                 print(f"There are {y[0]} entities in this table which the degree of violation is {x[0]}.\n")
            
            all_col = get_column_names(cursor, table_name)
            for num in range(len(all_col)):
                if all_col[num] in columns:
                    all_col[num] = "** " + all_col[num] + " **"
            all_col.insert(0, ' ')
            for key, value in duplicate_dic.items():
                print(f"Degree of Duplication: {key}")
                table_dup = PrettyTable()
                table_dup.field_names = all_col

                for idx, v in enumerate(value, start=1):
                    row = [idx] + v
                    table_dup.add_row(row)

                # print(table_dup)
                print()

    except Error as e:
        print("Error:", e)
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# %%
def degree_of_violation2(cursor, table_name, columns):
    if not columns:
        return {}
    
    # Query to find groups with duplicates (degree > 1)
    query_duplicates = f"""
        SELECT {', '.join([f"`{col}`" for col in columns])}, COUNT(*) AS group_count 
        FROM `{table_name}` 
        WHERE {' AND '.join([f"`{col}` IS NOT NULL" for col in columns])}
        GROUP BY {', '.join([f"`{col}`" for col in columns])}
        HAVING COUNT(*) > 1;
    """
    
    # Execute the query
    cursor.execute(query_duplicates)
    group_table = cursor.fetchall()

    # Process results for degrees
    duplicate_counts = {}
    for row in group_table:
        degree = row[-1]  # group_count is the last column
        # Increment the total number of rows for this degree
        duplicate_counts[degree] = duplicate_counts.get(degree, 0) + degree

    return duplicate_counts  # Contains total rows for each degree > 1


def plot_violation_pie_chart(columns, duplicate_counts):
    """
    Plot a pie chart for degrees of violation based on their total rows in all duplicates.
    
    :param duplicate_counts: A dictionary where keys are degrees and values are total rows.
    """
    # Prepare data
    x = list(duplicate_counts.keys())
    y = list(duplicate_counts.values())  # Total rows for each degree
    total = sum(y)  # Total rows across all degrees
    ratios = [count / total * 100 for count in y]  # Calculate ratios as percentages

    # Prepare labels for the pie chart
    labels = [f"Degree = {degree}" for degree in x]

    # Define colors for each segment
    colors = plt.cm.Paired.colors[:len(labels)]

    # Explode the first slice for emphasis
    explode = [0.1 if i == 0 else 0 for i in range(len(labels))]

    # Set font sizes globally
    plt.rcParams.update({
        'font.size': 20,       # General font size
        'axes.titlesize': 22,  # Title font size
        'axes.labelsize': 20   # Label font size
    })

    # Create the pie chart
    plt.figure(figsize=(10, 10))  # Increase figure size
    plt.pie(
        ratios,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90,
        colors=colors,
        explode=explode,
        wedgeprops={'edgecolor': 'black'},
        textprops={'fontsize': 20}  # Increase text font size
    )

    # Set the title and show the chart
    plt.title(f"Degrees of Violation Distribution under ({', '.join(columns)})", fontsize=22)
    plt.show()


# Example usage in main_degree
def main_degree2(database, table_name, columns):
    try:
        connection = mysql.connector.connect(user="root", password="yzh_20010315", database=database)

        if connection.is_connected():
            cursor = connection.cursor()

            # Get degree counts (degree > 1)
            duplicate_counts = degree_of_violation2(cursor, table_name, columns)
            # print("Duplicate Counts:", duplicate_counts)

            # Plot the pie chart
            plot_violation_pie_chart(columns, duplicate_counts)

    except Error as e:
        print("Error:", e)
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()
# for key in nk_dic.items():
#     print(key)
for key, values in nk_dic.items():
    for value in values:
        if value[1] != 1:
            print(f"\n==================== Table: {key}; Near-key: {value[0]} ====================\n")
            main_degree('hockey', key, value[0])
            main_degree2('hockey', key, value[0])
# Out:
# ==================== Table: awardsplayers; Near-key: ('playerID', 'year', 'pos') ====================
#
# There are 6 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: awardsplayers; Near-key: ('playerID', 'year', 'lgID', 'pos') ====================
#
# There are 6 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: coaches; Near-key: ('coachID', 'year') ====================
#
# There are 14 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: coaches; Near-key: ('year', 'tmID', 'stint') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: coaches; Near-key: ('coachID', 'year', 'tmID') ====================
#
# There are 5 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: coaches; Near-key: ('coachID', 'year', 'lgID') ====================
#
# There are 14 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: coaches; Near-key: ('year', 'tmID', 'lgID', 'stint') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: coaches; Near-key: ('coachID', 'year', 'tmID', 'lgID') ====================
#
# There are 5 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('month', 'IDgoalie1') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('month', 'IDgoalie2') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('tmID', 'oppID') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('oppID', 'IDgoalie1') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('month', 'R/P', 'IDgoalie2') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('tmID', 'oppID', 'R/P') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('tmID', 'oppID', 'IDgoalie1') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('oppID', 'R/P', 'IDgoalie1') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: combinedshutouts; Near-key: ('tmID', 'oppID', 'R/P', 'IDgoalie1') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('playerID', 'year', 'tmID') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('playerID', 'year', 'GP') ====================
#
# There are 11 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('year', 'tmID', 'GP') ====================
# Degree of Duplication: 3
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('playerID', 'year', 'tmID', 'lgID') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('playerID', 'year', 'lgID', 'GP') ====================
#
# There are 11 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('year', 'stint', 'tmID', 'GP') ====================
# Degree of Duplication: 3
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('year', 'tmID', 'lgID', 'GP') ====================
# Degree of Duplication: 3
#
# Degree of Duplication: 2
# ==================== Table: goalies; Near-key: ('year', 'stint', 'tmID', 'lgID', 'GP') ====================
# Degree of Duplication: 3
#
# Degree of Duplication: 2
# ==================== Table: goaliesshootout; Near-key: ('playerID', 'year') ====================
#
# There are 11 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: hof; Near-key: ('name',) ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: hof; Near-key: ('name', 'category') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: master; Near-key: ('lastName', 'nameGiven') ====================
#
# There are 6 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: master; Near-key: ('lastName', 'birthYear') ====================
# Degree of Duplication: 2
#
# Degree of Duplication: 3
# ==================== Table: master; Near-key: ('lastName', 'nameGiven', 'pos') ====================
#
# There are 1 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: master; Near-key: ('lastName', 'birthYear', 'pos') ====================
#
# There are 23 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: master; Near-key: ('nameGiven', 'birthYear', 'pos') ====================
# Degree of Duplication: 2
#
# Degree of Duplication: 3
#
# Degree of Duplication: 4
# ==================== Table: scoring; Near-key: ('playerID', 'year', 'stint') ====================
#
# There are 2 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: scoring; Near-key: ('playerID', 'year', 'tmID') ====================
#
# There are 9 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: scoring; Near-key: ('playerID', 'year', 'stint', 'lgID') ====================
#
# There are 2 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: scoring; Near-key: ('playerID', 'year', 'tmID', 'lgID') ====================
#
# There are 9 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: scoring; Near-key: ('playerID', 'year', 'tmID', 'pos') ====================
#
# There are 9 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: scoring; Near-key: ('playerID', 'year', 'tmID', 'lgID', 'pos') ====================
#
# There are 9 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: seriespost; Near-key: ('year', 'tmIDLoser') ====================
#
# There are 3 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: seriespost; Near-key: ('year', 'lgIDWinner', 'tmIDLoser') ====================
#
# There are 2 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: seriespost; Near-key: ('year', 'tmIDLoser', 'lgIDLoser') ====================
#
# There are 3 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
# ==================== Table: seriespost; Near-key: ('year', 'lgIDWinner', 'tmIDLoser', 'lgIDLoser') ====================
#
# There are 2 entities in this table which the degree of violation is 2.
#
# Degree of Duplication: 2
